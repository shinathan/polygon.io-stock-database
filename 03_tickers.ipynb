# %% [markdown]
# # 3.1 Tickers
# The goal is to solve the problems of the Polygon ticker lists in the introduction. Before we do that we will download the ticker list for all days from Polygon and store them into the map <code>tickers</code>.

# %%
###
from polygon.rest import RESTClient
from datetime import datetime, date, time, timedelta
from pytz import timezone
from functools import lru_cache
from utils import get_market_dates, first_trading_date_after_equal, last_trading_date_before_equal, get_tickers
import os
import pytz
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import mplfinance as mpf

POLYGON_DATA_PATH = "../data/polygon/"

START_DATE = date(2019, 1, 1)
END_DATE = date(2023, 9, 7)

with open(POLYGON_DATA_PATH + "secret.txt") as f:
    KEY = next(f).strip()

client = RESTClient(api_key=KEY)

# %% [markdown]
# First, I will create a function to download the ticker for a specific date.

# %%
###
def download_tickers(date_):
    """Retrieve the ticker list for a specific date

    Args:
        date_ (Date): the Date for which to download the ticker list

    Returns:
        DataFrame: the ticker list
    """
    
    date_iso = date_.isoformat()

    ticker_list_iterator_active = client.list_tickers(type="CS", date=date_iso, active=True, market='stocks', limit=1000)
    ticker_list_iterator_delisted = client.list_tickers(type="CS", date=date_iso, active=False, market='stocks', limit=1000)
    ticker_list_iterator_active_adr = client.list_tickers(type="ADRC", date=date_iso, active=True, market='stocks', limit=1000)
    ticker_list_iterator_delisted_adr = client.list_tickers(type="ADRC", date=date_iso, active=False, market='stocks', limit=1000)
    tickers_active = pd.DataFrame(ticker_list_iterator_active)
    tickers_delisted = pd.DataFrame(ticker_list_iterator_delisted)
    tickers_active_adr = pd.DataFrame(ticker_list_iterator_active_adr)
    tickers_delisted_adr = pd.DataFrame(ticker_list_iterator_delisted_adr)

    tickers_all = pd.concat([tickers_active, tickers_delisted, tickers_active_adr, tickers_delisted_adr])
    tickers_all.sort_values(by = "ticker", inplace=True)
    tickers_all.reset_index(inplace=True, drop=True)
    return tickers_all[['ticker', 'name', 'active', 'delisted_utc', 'last_updated_utc', 'cik', 'composite_figi', 'type']]

# %% [markdown]
# Then all ticker lists are downloaded and stored in the <code>raw/tickers/</code> map. But only the one that we need if we already have some.

# %%
###
# Get a list of what we already have
files = os.listdir(POLYGON_DATA_PATH + f'raw/tickers')
available_dates = [date.fromisoformat(file.replace(".csv", "")) for file in files]

trading_dates = get_market_dates()
for day in trading_dates:
    # Only download what we do not have
    if day >= START_DATE and day <= END_DATE and day not in available_dates:
        tickers = download_tickers(day)
        tickers.to_csv(POLYGON_DATA_PATH + f"raw/tickers/{day.isoformat()}.csv")
        print(f"Downloaded tickers for {day.isoformat()}")

# %%
trading_dates[-1]
# Out:
# datetime.date(2023, 9, 7)

# %% [markdown]
# A random ticker list:

# %%
pd.read_csv(POLYGON_DATA_PATH + f"raw/tickers/2022-06-09.csv", index_col=0).head(3)
# Out:
#   ticker                       name  active          delisted_utc  \
# 0      A  Agilent Technologies Inc.    True                   NaN
# 1     AA                Alcoa, Inc.   False  2016-11-01T00:00:00Z
# 2     AA                  ALCOA INC   False  2016-10-07T00:00:00Z
#
#        last_updated_utc        cik composite_figi type
# 0  2022-06-14T00:00:00Z  1090872.0   BBG000C2V3D6   CS
# 1  2016-11-01T00:00:00Z     4281.0            NaN   CS
# 2  2016-10-07T00:00:00Z     4281.0            NaN   CS

# %% [markdown]
# We observe that the <code>last_updated_utc</code> does not match the date of the ticker list. For example for "A", this date is *after* 2022-06-09. So this value is not point-in-time. So this value is useless for us. Neither do we need <code>delisted_utc</code>, because we will determine the <code>end_date</code> by the ticker lists themselves. We will also determine the <code>start_date</code>, which Polygon does not give at all.
#
# Later when we do have data, we will create a new column <code>start_data</code> and <code>end_data</code> which gives the start and end dates from the available data.

# %% [markdown]
# # 3.2 Building the tickers loop
# Now we can finally create our ticker list, which includes all tickers. The process involves looping over all Polygon ticker lists and updating our own one. First some notation: T is our ticker list that we iteratively update using Polygons ticker list. P(i) is the Polygon ticker list from day *i*.
#
# 1. On day 1, our ticker list is the same as the one from Polygon, but with some extra columns. We create a column <code>start_date</code> which is day 1 and <code>end_date</code> with is empty. We are only interested in stocks that were active on that day.
# 2. For all *i = 2 ... n* days, for the active stocks:
#     * **Delistings**: The stocks that are in T but not in P(i) are the stocks that are removed by Polygon (e.g. FB). For these tickers we set the <code>end_date</code> in T to day *i-1*.
#     * **New listings**: The stocks that are in P(i) but not in T are the new listings. We will append the new stock to T and set the start_date to day *i*.
#     * **Everything else**: The stocks that are both in P(i) and T are the stocks that 'continue their listings'. We do nothing.
#
# Two tickers are the 'same' if all fields except <code>last_updated_utc</code> or <code>delisted_utc</code> are the same.
#
# For testing, we will start with 2022-06-08 and update to 2022-06-09. Both FB and META should then be included with the correct start and end dates. The start and end date of FB should be 2022-06-08 and the start date of META should be 2022-06-09. The end date of META should be empty.

# %%
day_1 = date(2022, 6, 8)
day_2 = date(2022, 6, 9)

our_tickers = pd.read_csv(
    POLYGON_DATA_PATH + f"raw/tickers/{day_1.isoformat()}.csv",
    index_col=0,
)
our_tickers = our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]]
our_tickers = our_tickers[our_tickers["active"] == True]
our_tickers.reset_index(inplace=True, drop=True)

our_tickers["start_date"] = day_1
our_tickers["end_date"] = pd.NaT

tickers_day_2 = pd.read_csv(
    POLYGON_DATA_PATH + f"raw/tickers/{day_2.isoformat()}.csv",
    index_col=0,
)
tickers_day_2 = tickers_day_2[["ticker", "name", "active", "cik", "composite_figi", "type"]]
tickers_day_2 = tickers_day_2[tickers_day_2["active"] == True]
tickers_day_2.reset_index(inplace=True, drop=True)

# %%
our_tickers.head(2)
# Out:
#   ticker                       name  active        cik composite_figi type  \
# 0      A  Agilent Technologies Inc.    True  1090872.0   BBG000C2V3D6   CS
# 1     AA          Alcoa Corporation    True  1675149.0   BBG00B3T3HD3   CS
#
#    start_date end_date
# 0  2022-06-08      NaT
# 1  2022-06-08      NaT

# %%
tickers_day_2.head(2)
# Out:
#   ticker                       name  active        cik composite_figi type
# 0      A  Agilent Technologies Inc.    True  1090872.0   BBG000C2V3D6   CS
# 1     AA          Alcoa Corporation    True  1675149.0   BBG00B3T3HD3   CS

# %% [markdown]
# Preliminary check for duplicates

# %%
# Preliminary check: no duplicates
if our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
    raise Exception("There are duplicates!")

if tickers_day_2[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
    raise Exception("There are duplicates!")

# %% [markdown]
# We will first get the delisting and new listings. (Nothing has to be done with the kept listings).

# %%
# DELISTINGS: Get tickers that are in T but not in P(2). This is actually not straightforward (https://stackoverflow.com/questions/28901683/pandas-get-rows-which-are-not-in-other-dataframe). We need to get the rows in tickers_day_2 that are not in our_tickers. We will use the merge function but specifying indicator=True and use a left merge (tickers_day_2 left merge to our_tickers). What gets returned is a dataframe with the flags "left_only", "right_only" and "both". If the indicator is "left_only", it means that it existed in only in the left DataFrame (our_tickers). This is exactly what we need. 
indicator_delisted = our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(tickers_day_2[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], 
                   how='left', indicator=True)
indicator_delisted = indicator_delisted["_merge"] # Only get the indicator

delisted_tickers = our_tickers[indicator_delisted == "left_only"] # Only get the delisted tickers

# NEW LISTINGS: Swap the DataFrames
indicator_new = tickers_day_2[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], 
                   how='left', indicator=True)
indicator_new = indicator_new["_merge"]
new_tickers = tickers_day_2[indicator_new == "left_only"]

# KEPT LISTINGS
current_tickers = our_tickers[indicator_delisted == "both"]
# current_tickers = tickers_day_2[indicator_new == "both"] # It does not matter which one we choose

# %%
print(len(delisted_tickers))
delisted_tickers.head(2)
# Out:
# 6
#      ticker                                               name  active  \
# 1144   CERN                                        Cerner Corp    True
# 1799   DYNS  Dynamics Special Purpose Corp. Class A Common ...    True
#
#             cik composite_figi type  start_date end_date
# 1144   804753.0   BBG000BFDLV8   CS  2022-06-08      NaT
# 1799  1854270.0   BBG010WX7ZB3   CS  2022-06-08      NaT

# %%
print(len(new_tickers))
new_tickers.head(2)
# Out:
# 5
#      ticker                                   name  active        cik  \
# 2435   GLAQ  Globis Acquisition Corp. common stock    True  1823383.0
# 2725   HOUS              Anywhere Real Estate Inc.    True  1398987.0
#
#      composite_figi type
# 2435            NaN   CS
# 2725   BBG000QN4GY3   CS

# %%
len(current_tickers)
# Out:
# 6275

# %% [markdown]
# Then we will process the delistings and listings.

# %%
# DELISTINGS: register delisting date and set to inactive.
our_tickers.loc[indicator_delisted == "left_only", "end_date"] = day_1 #Not day_2!
our_tickers.loc[indicator_delisted == "left_only", "active"] = False

our_tickers[our_tickers["ticker"] == "FB"]
# Out:
#      ticker                                       name  active        cik  \
# 2080     FB  Meta Platforms, Inc. Class A Common Stock   False  1326801.0
#
#      composite_figi type  start_date    end_date
# 2080   BBG000MM2P62   CS  2022-06-08  2022-06-08

# %%
# NEW LISTINGS: append the new tickers and register start date
print(len(our_tickers))
print(len(new_tickers))

our_tickers = pd.concat([our_tickers, new_tickers])
our_tickers.reset_index(inplace=True, drop=True)
our_tickers['start_date'].fillna(value=day_2, inplace=True)

print(len(our_tickers))
our_tickers[our_tickers["ticker"] == "META"]
# Out:
# 6281
# 5
# 6286
#      ticker                                       name  active        cik  \
# 6283   META  Meta Platforms, Inc. Class A Common Stock    True  1326801.0
#
#      composite_figi type  start_date end_date
# 6283   BBG000MM2P62   CS  2022-06-09      NaN

# %% [markdown]
# Some final checks and setting <code>end_date</code> for the active listings at END_DATE.

# %%
if our_tickers[["ticker", "name", "active", "type", "start_date"]].isnull().values.any():
    raise Exception("There are missing values.")

# After all is done, set the end_date for active stocks to the new day. This is only done after all iterations. 
our_tickers["end_date"].fillna(value=day_2, inplace=True)

# %% [markdown]
# The result is correct. FB is included with the correct <code>end_date</code>. Then META starts with the correct <code>start_date</code>.

# %%
our_tickers[our_tickers['ticker'].isin(['FB', 'META'])]
# Out:
#      ticker                                       name  active        cik  \
# 2080     FB  Meta Platforms, Inc. Class A Common Stock   False  1326801.0
# 6283   META  Meta Platforms, Inc. Class A Common Stock    True  1326801.0
#
#      composite_figi type  start_date    end_date
# 2080   BBG000MM2P62   CS  2022-06-08  2022-06-08
# 6283   BBG000MM2P62   CS  2022-06-09  2022-06-09

# %% [markdown]
# # 3.3 The tickers loop
# Putting it all in a loop gives the following code. We save the results to <code>tickers_v1.csv</code>.

# %%
market_days = get_market_dates()

first_trading_date_after_start_date = first_trading_date_after_equal(START_DATE)
last_trading_date_before_end_date = last_trading_date_before_equal(END_DATE)

for day in market_days:
    if day == first_trading_date_after_start_date:
        # At the start, our ticker list is the same as polygon.
        our_tickers = pd.read_csv(
            POLYGON_DATA_PATH + f"raw/tickers/{first_trading_date_after_start_date.isoformat()}.csv",
            index_col=0,
            keep_default_na=False,
            na_values=['#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NULL', 'NaN', 'None', 'n/a', 'nan', 'null']
        ) #There is a stock named 'NA'. We have to avoid pandas treating it as a N/A value.
        our_tickers = our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]]
        our_tickers = our_tickers[our_tickers["active"] == True]
        our_tickers.reset_index(inplace=True, drop=True)
    
        # Initialize tickers_all
        our_tickers["start_date"] = START_DATE
        our_tickers["end_date"] = pd.NaT

    elif day > START_DATE and day <= END_DATE:
        # Get new ticker list to update ours
        tickers_day_i = pd.read_csv(
            POLYGON_DATA_PATH + f"raw/tickers/{day.isoformat()}.csv",
            index_col=0,
            keep_default_na=False,
            na_values=['#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NULL', 'NaN', 'None', 'n/a', 'nan', 'null']
        )
        tickers_day_i = tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]]
        tickers_day_i = tickers_day_i[tickers_day_i["active"] == True]
        tickers_day_i.reset_index(inplace=True, drop=True)

        # Preliminary check: no duplicates
        if our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
            raise Exception("There are duplicates!")

        if tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
            raise Exception("There are duplicates!")

        # DELISTINGS
        indicator_delisted = our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], how='left', indicator=True)

        indicator_delisted['_merge'] = np.where(our_tickers["active"], indicator_delisted['_merge'], "both") # ERROR FIX: If in our ticker list we have already set it inactive, it should not be added to the list of delisted stocks again. By setting _merge to "both" we skip the already inactive stocks.

        indicator_delisted = indicator_delisted["_merge"] # Only get the indicator
        delisted_tickers = our_tickers[indicator_delisted == "left_only"]

        # NEW LISTINGS
        indicator_new = tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], 
                        how='left', indicator=True)
        indicator_new = indicator_new["_merge"]
        new_tickers = tickers_day_i[indicator_new == "left_only"]

        # PROCESS DELISTINGS
        previous_day = market_days[market_days.index(day) - 1] # Getting previous trading day
        our_tickers.loc[indicator_delisted == "left_only", "end_date"] = previous_day
        our_tickers.loc[indicator_delisted == "left_only", "active"] = False
        
        # PROCESS NEW LISTINGS
        our_tickers = pd.concat([our_tickers, new_tickers])
        our_tickers.reset_index(inplace=True, drop=True)
        our_tickers['start_date'].fillna(value=day, inplace=True)

        # Final checks
        if our_tickers[["ticker", "name", "active", "type", "start_date"]].isnull().values.any():
            #null_data = our_tickers[our_tickers[["ticker", "name", "active", "type", "start_date"]].isnull().any(axis=1)]
            raise Exception("There are missing values.")
        
        print(f'{day.isoformat()}: Amount of stocks {len(our_tickers)}')
        
        # Finalize
        if day == last_trading_date_before_end_date:
            our_tickers["end_date"].fillna(value=last_trading_date_before_end_date, inplace=True)
            our_tickers = our_tickers.sort_values(by=["ticker", "end_date"]).reset_index(drop=True)
            our_tickers[["ticker", "name", "active", "start_date", "end_date", "type", "cik", "composite_figi"]].to_csv("../data/tickers_v1.csv")
# Out:
# Out of range! Returning input.
# 2019-01-03: Amount of stocks 4956
# 2019-01-04: Amount of stocks 4960
# 2019-01-07: Amount of stocks 4963
# 2019-01-08: Amount of stocks 4966
# 2019-01-09: Amount of stocks 4969
# 2019-01-10: Amount of stocks 4981
# 2019-01-11: Amount of stocks 4983
# 2019-01-14: Amount of stocks 4984
# 2019-01-15: Amount of stocks 4984
# 2019-01-16: Amount of stocks 4984
# 2019-01-17: Amount of stocks 4987
# 2019-01-18: Amount of stocks 4988
# 2019-01-22: Amount of stocks 4988
# 2019-01-23: Amount of stocks 4989
# 2019-01-24: Amount of stocks 4990
# 2019-01-25: Amount of stocks 4991
# 2019-01-28: Amount of stocks 4991
# 2019-01-29: Amount of stocks 4992
# 2019-01-30: Amount of stocks 4993
# 2019-01-31: Amount of stocks 4994
# 2019-02-01: Amount of stocks 4995
# 2019-02-04: Amount of stocks 5000
# 2019-02-05: Amount of stocks 5000
# 2019-02-06: Amount of stocks 5001
# 2019-02-07: Amount of stocks 5003
# 2019-02-08: Amount of stocks 5008
# 2019-02-11: Amount of stocks 5010
# 2019-02-12: Amount of stocks 5013
# 2019-02-13: Amount of stocks 5016
# 2019-02-14: Amount of stocks 5022
# 2019-02-15: Amount of stocks 5024
# 2019-02-19: Amount of stocks 5029
# 2019-02-20: Amount of stocks 5032
# 2019-02-21: Amount of stocks 5035
# 2019-02-22: Amount of stocks 5038
# 2019-02-25: Amount of stocks 5041
# 2019-02-26: Amount of stocks 5043
# 2019-02-27: Amount of stocks 5045
# 2019-02-28: Amount of stocks 5047
# 2019-03-01: Amount of stocks 5049
# 2019-03-04: Amount of stocks 5052
# 2019-03-05: Amount of stocks 5054
# 2019-03-06: Amount of stocks 5058
# 2019-03-07: Amount of stocks 5060
# 2019-03-08: Amount of stocks 5062
# 2019-03-11: Amount of stocks 5065
# 2019-03-12: Amount of stocks 5066
# 2019-03-13: Amount of stocks 5071
# 2019-03-14: Amount of stocks 5073
# 2019-03-15: Amount of stocks 5075
# 2019-03-18: Amount of stocks 5083
# 2019-03-19: Amount of stocks 5087
# 2019-03-20: Amount of stocks 5092
# 2019-03-21: Amount of stocks 5092
# 2019-03-22: Amount of stocks 5092
# 2019-03-25: Amount of stocks 5095
# 2019-03-26: Amount of stocks 5098
# 2019-03-27: Amount of stocks 5101
# 2019-03-28: Amount of stocks 5106
# 2019-03-29: Amount of stocks 5112
# 2019-04-01: Amount of stocks 5115
# 2019-04-02: Amount of stocks 5560
# 2019-04-03: Amount of stocks 5563
# 2019-04-04: Amount of stocks 5568
# 2019-04-05: Amount of stocks 5571
# 2019-04-08: Amount of stocks 5573
# 2019-04-09: Amount of stocks 5576
# 2019-04-10: Amount of stocks 5579
# 2019-04-11: Amount of stocks 5580
# 2019-04-12: Amount of stocks 5583
# 2019-04-15: Amount of stocks 5588
# 2019-04-16: Amount of stocks 5591
# 2019-04-17: Amount of stocks 5599
# 2019-04-18: Amount of stocks 5606
# 2019-04-22: Amount of stocks 5611
# 2019-04-23: Amount of stocks 5612
# 2019-04-24: Amount of stocks 5613
# 2019-04-25: Amount of stocks 5615
# 2019-04-26: Amount of stocks 5618
# 2019-04-29: Amount of stocks 5623
# 2019-04-30: Amount of stocks 5626
# 2019-05-01: Amount of stocks 5628
# 2019-05-02: Amount of stocks 5635
# 2019-05-03: Amount of stocks 5640
# 2019-05-06: Amount of stocks 5641
# 2019-05-07: Amount of stocks 5644
# 2019-05-08: Amount of stocks 5648
# 2019-05-09: Amount of stocks 5663
# 2019-05-10: Amount of stocks 5670
# 2019-05-13: Amount of stocks 5673
# 2019-05-14: Amount of stocks 5676
# 2019-05-15: Amount of stocks 5679
# 2019-05-16: Amount of stocks 5684
# 2019-05-17: Amount of stocks 5684
# 2019-05-20: Amount of stocks 5688
# 2019-05-21: Amount of stocks 5691
# 2019-05-22: Amount of stocks 5692
# 2019-05-23: Amount of stocks 5695
# 2019-05-24: Amount of stocks 5698
# 2019-05-28: Amount of stocks 5698
# 2019-05-29: Amount of stocks 5700
# 2019-05-30: Amount of stocks 5700
# 2019-05-31: Amount of stocks 5700
# 2019-06-03: Amount of stocks 5710
# 2019-06-04: Amount of stocks 5711
# 2019-06-05: Amount of stocks 5715
# 2019-06-06: Amount of stocks 5732
# 2019-06-07: Amount of stocks 5751
# 2019-06-10: Amount of stocks 5771
# 2019-06-11: Amount of stocks 5777
# 2019-06-12: Amount of stocks 5781
# 2019-06-13: Amount of stocks 5785
# 2019-06-14: Amount of stocks 5788
# 2019-06-17: Amount of stocks 5797
# 2019-06-18: Amount of stocks 5798
# 2019-06-19: Amount of stocks 5801
# 2019-06-20: Amount of stocks 5812
# 2019-06-21: Amount of stocks 5816
# 2019-06-24: Amount of stocks 5817
# 2019-06-25: Amount of stocks 5822
# 2019-06-26: Amount of stocks 5824
# 2019-06-27: Amount of stocks 5830
# 2019-06-28: Amount of stocks 5835
# 2019-07-01: Amount of stocks 5842
# 2019-07-02: Amount of stocks 5846
# 2019-07-03: Amount of stocks 5852
# 2019-07-05: Amount of stocks 5855
# 2019-07-08: Amount of stocks 5857
# 2019-07-09: Amount of stocks 5857
# 2019-07-10: Amount of stocks 5857
# 2019-07-11: Amount of stocks 5857
# 2019-07-12: Amount of stocks 5858
# 2019-07-15: Amount of stocks 5864
# 2019-07-16: Amount of stocks 5865
# 2019-07-17: Amount of stocks 5874
# 2019-07-18: Amount of stocks 5883
# 2019-07-19: Amount of stocks 5885
# 2019-07-22: Amount of stocks 5887
# 2019-07-23: Amount of stocks 5891
# 2019-07-24: Amount of stocks 5897
# 2019-07-25: Amount of stocks 5902
# 2019-07-26: Amount of stocks 5906
# 2019-07-29: Amount of stocks 5910
# 2019-07-30: Amount of stocks 5911
# 2019-07-31: Amount of stocks 5915
# 2019-08-01: Amount of stocks 5923
# 2019-08-02: Amount of stocks 5925
# 2019-08-05: Amount of stocks 5939
# 2019-08-06: Amount of stocks 5940
# 2019-08-07: Amount of stocks 5943
# 2019-08-08: Amount of stocks 6000
# 2019-08-09: Amount of stocks 6338
# 2019-08-12: Amount of stocks 6808
# 2019-08-13: Amount of stocks 6808
# 2019-08-14: Amount of stocks 7203
# 2019-08-15: Amount of stocks 7439
# 2019-08-16: Amount of stocks 7439
# 2019-08-19: Amount of stocks 7569
# 2019-08-20: Amount of stocks 7592
# 2019-08-21: Amount of stocks 7593
# 2019-08-22: Amount of stocks 7596
# 2019-08-23: Amount of stocks 7596
# 2019-08-26: Amount of stocks 7597
# 2019-08-27: Amount of stocks 7598
# 2019-08-28: Amount of stocks 7599
# 2019-08-29: Amount of stocks 7600
# 2019-08-30: Amount of stocks 7607
# 2019-09-03: Amount of stocks 7614
# 2019-09-04: Amount of stocks 7614
# 2019-09-05: Amount of stocks 7616
# 2019-09-06: Amount of stocks 7617
# 2019-09-09: Amount of stocks 7620
# 2019-09-10: Amount of stocks 7620
# 2019-09-11: Amount of stocks 7625
# 2019-09-12: Amount of stocks 7631
# 2019-09-13: Amount of stocks 7633
# 2019-09-16: Amount of stocks 7637
# 2019-09-17: Amount of stocks 7639
# 2019-09-18: Amount of stocks 7639
# 2019-09-19: Amount of stocks 7646
# 2019-09-20: Amount of stocks 7646
# 2019-09-23: Amount of stocks 7646
# 2019-09-24: Amount of stocks 7648
# 2019-09-25: Amount of stocks 7650
# 2019-09-26: Amount of stocks 7652
# 2019-09-27: Amount of stocks 7654
# 2019-09-30: Amount of stocks 7656
# 2019-10-01: Amount of stocks 7662
# 2019-10-02: Amount of stocks 7664
# 2019-10-03: Amount of stocks 7669
# 2019-10-04: Amount of stocks 7670
# 2019-10-07: Amount of stocks 7673
# 2019-10-08: Amount of stocks 7673
# 2019-10-09: Amount of stocks 7674
# 2019-10-10: Amount of stocks 7677
# 2019-10-11: Amount of stocks 7679
# 2019-10-14: Amount of stocks 7679
# 2019-10-15: Amount of stocks 7681
# 2019-10-16: Amount of stocks 7683
# 2019-10-17: Amount of stocks 7688
# 2019-10-18: Amount of stocks 7692
# 2019-10-21: Amount of stocks 7694
# 2019-10-22: Amount of stocks 7696
# 2019-10-23: Amount of stocks 7698
# 2019-10-24: Amount of stocks 7702
# 2019-10-25: Amount of stocks 7710
# 2019-10-28: Amount of stocks 7713
# 2019-10-29: Amount of stocks 7718
# 2019-10-30: Amount of stocks 7718
# 2019-10-31: Amount of stocks 7722
# 2019-11-01: Amount of stocks 7730
# 2019-11-04: Amount of stocks 7730
# 2019-11-05: Amount of stocks 7735
# 2019-11-06: Amount of stocks 7737
# 2019-11-07: Amount of stocks 7741
# 2019-11-08: Amount of stocks 7751
# 2019-11-11: Amount of stocks 7753
# 2019-11-12: Amount of stocks 7753
# 2019-11-13: Amount of stocks 7753
# 2019-11-14: Amount of stocks 7759
# 2019-11-15: Amount of stocks 7762
# 2019-11-18: Amount of stocks 7765
# 2019-11-19: Amount of stocks 7768
# 2019-11-20: Amount of stocks 7769
# 2019-11-21: Amount of stocks 7774
# 2019-11-22: Amount of stocks 7775
# 2019-11-25: Amount of stocks 7778
# 2019-11-26: Amount of stocks 7781
# 2019-11-27: Amount of stocks 7781
# 2019-11-29: Amount of stocks 7784
# 2019-12-02: Amount of stocks 7785
# 2019-12-03: Amount of stocks 7786
# 2019-12-04: Amount of stocks 7788
# 2019-12-05: Amount of stocks 7793
# 2019-12-06: Amount of stocks 7794
# 2019-12-09: Amount of stocks 7798
# 2019-12-10: Amount of stocks 7799
# 2019-12-11: Amount of stocks 7801
# 2019-12-12: Amount of stocks 7806
# 2019-12-13: Amount of stocks 7807
# 2019-12-16: Amount of stocks 7809
# 2019-12-17: Amount of stocks 7812
# 2019-12-18: Amount of stocks 7814
# 2019-12-19: Amount of stocks 7818
# 2019-12-20: Amount of stocks 7822
# 2019-12-23: Amount of stocks 7826
# 2019-12-24: Amount of stocks 7827
# 2019-12-26: Amount of stocks 7828
# 2019-12-27: Amount of stocks 7830
# 2019-12-30: Amount of stocks 7833
# 2019-12-31: Amount of stocks 7834
# 2020-01-02: Amount of stocks 7842
# 2020-01-03: Amount of stocks 7842
# 2020-01-06: Amount of stocks 7848
# 2020-01-07: Amount of stocks 7851
# 2020-01-08: Amount of stocks 7852
# 2020-01-09: Amount of stocks 7856
# 2020-01-10: Amount of stocks 7863
# 2020-01-13: Amount of stocks 7864
# 2020-01-14: Amount of stocks 7867
# 2020-01-15: Amount of stocks 7870
# 2020-01-16: Amount of stocks 7874
# 2020-01-17: Amount of stocks 7878
# 2020-01-21: Amount of stocks 7880
# 2020-01-22: Amount of stocks 7880
# 2020-01-23: Amount of stocks 7883
# 2020-01-24: Amount of stocks 7884
# 2020-01-27: Amount of stocks 7885
# 2020-01-28: Amount of stocks 7889
# 2020-01-29: Amount of stocks 7892
# 2020-01-30: Amount of stocks 7894
# 2020-01-31: Amount of stocks 7898
# 2020-02-03: Amount of stocks 7905
# 2020-02-04: Amount of stocks 7906
# 2020-02-05: Amount of stocks 7908
# 2020-02-06: Amount of stocks 7914
# 2020-02-07: Amount of stocks 7918
# 2020-02-10: Amount of stocks 7921
# 2020-02-11: Amount of stocks 7922
# 2020-02-12: Amount of stocks 7927
# 2020-02-13: Amount of stocks 7931
# 2020-02-14: Amount of stocks 7933
# 2020-02-18: Amount of stocks 7935
# 2020-02-19: Amount of stocks 7939
# 2020-02-20: Amount of stocks 7941
# 2020-02-21: Amount of stocks 7943
# 2020-02-24: Amount of stocks 7945
# 2020-02-25: Amount of stocks 7945
# 2020-02-26: Amount of stocks 7946
# 2020-02-27: Amount of stocks 7947
# 2020-02-28: Amount of stocks 7950
# 2020-03-02: Amount of stocks 7954
# 2020-03-03: Amount of stocks 7959
# 2020-03-04: Amount of stocks 7959
# 2020-03-05: Amount of stocks 7961
# 2020-03-06: Amount of stocks 7964
# 2020-03-09: Amount of stocks 7965
# 2020-03-10: Amount of stocks 7965
# 2020-03-11: Amount of stocks 7966
# 2020-03-12: Amount of stocks 7968
# 2020-03-13: Amount of stocks 7972
# 2020-03-16: Amount of stocks 7977
# 2020-03-17: Amount of stocks 7978
# 2020-03-18: Amount of stocks 7984
# 2020-03-19: Amount of stocks 7987
# 2020-03-20: Amount of stocks 7989
# 2020-03-23: Amount of stocks 7990
# 2020-03-24: Amount of stocks 7990
# 2020-03-25: Amount of stocks 7991
# 2020-03-26: Amount of stocks 7992
# 2020-03-27: Amount of stocks 7993
# 2020-03-30: Amount of stocks 7994
# 2020-03-31: Amount of stocks 7996
# 2020-04-01: Amount of stocks 7999
# 2020-04-02: Amount of stocks 8002
# 2020-04-03: Amount of stocks 8008
# 2020-04-06: Amount of stocks 8008
# 2020-04-07: Amount of stocks 8009
# 2020-04-08: Amount of stocks 8012
# 2020-04-09: Amount of stocks 8016
# 2020-04-13: Amount of stocks 8019
# 2020-04-14: Amount of stocks 8020
# 2020-04-15: Amount of stocks 8025
# 2020-04-16: Amount of stocks 8026
# 2020-04-17: Amount of stocks 8026
# 2020-04-20: Amount of stocks 8028
# 2020-04-21: Amount of stocks 8028
# 2020-04-22: Amount of stocks 8028
# 2020-04-23: Amount of stocks 8028
# 2020-04-24: Amount of stocks 8030
# 2020-04-27: Amount of stocks 8031
# 2020-04-28: Amount of stocks 8031
# 2020-04-29: Amount of stocks 8032
# 2020-04-30: Amount of stocks 8033
# 2020-05-01: Amount of stocks 8036
# 2020-05-04: Amount of stocks 8038
# 2020-05-05: Amount of stocks 8040
# 2020-05-06: Amount of stocks 8042
# 2020-05-07: Amount of stocks 8043
# 2020-05-08: Amount of stocks 8050
# 2020-05-11: Amount of stocks 8057
# 2020-05-12: Amount of stocks 8059
# 2020-05-13: Amount of stocks 8059
# 2020-05-14: Amount of stocks 8060
# 2020-05-15: Amount of stocks 8061
# 2020-05-18: Amount of stocks 8063
# 2020-05-19: Amount of stocks 8063
# 2020-05-20: Amount of stocks 8070
# 2020-05-21: Amount of stocks 8070
# 2020-05-22: Amount of stocks 8072
# 2020-05-26: Amount of stocks 8075
# 2020-05-27: Amount of stocks 8077
# 2020-05-28: Amount of stocks 8079
# 2020-05-29: Amount of stocks 8082
# 2020-06-01: Amount of stocks 8085
# 2020-06-02: Amount of stocks 8089
# 2020-06-03: Amount of stocks 8092
# 2020-06-04: Amount of stocks 8096
# 2020-06-05: Amount of stocks 8100
# 2020-06-08: Amount of stocks 8101
# 2020-06-09: Amount of stocks 8103
# 2020-06-10: Amount of stocks 8105
# 2020-06-11: Amount of stocks 8110
# 2020-06-12: Amount of stocks 8119
# 2020-06-15: Amount of stocks 8120
# 2020-06-16: Amount of stocks 8125
# 2020-06-17: Amount of stocks 8126
# 2020-06-18: Amount of stocks 8129
# 2020-06-19: Amount of stocks 8136
# 2020-06-22: Amount of stocks 8138
# 2020-06-23: Amount of stocks 8139
# 2020-06-24: Amount of stocks 8140
# 2020-06-25: Amount of stocks 8144
# 2020-06-26: Amount of stocks 8150
# 2020-06-29: Amount of stocks 8151
# 2020-06-30: Amount of stocks 8154
# 2020-07-01: Amount of stocks 8163
# 2020-07-02: Amount of stocks 8170
# 2020-07-06: Amount of stocks 8173
# 2020-07-07: Amount of stocks 8175
# 2020-07-08: Amount of stocks 8179
# 2020-07-09: Amount of stocks 8179
# 2020-07-10: Amount of stocks 8184
# 2020-07-13: Amount of stocks 8186
# 2020-07-14: Amount of stocks 8187
# 2020-07-15: Amount of stocks 8189
# 2020-07-16: Amount of stocks 8193
# 2020-07-17: Amount of stocks 8200
# 2020-07-20: Amount of stocks 8201
# 2020-07-21: Amount of stocks 8202
# 2020-07-22: Amount of stocks 8205
# 2020-07-23: Amount of stocks 8210
# 2020-07-24: Amount of stocks 8216
# 2020-07-27: Amount of stocks 8218
# 2020-07-28: Amount of stocks 8222
# 2020-07-29: Amount of stocks 8223
# 2020-07-30: Amount of stocks 8232
# 2020-07-31: Amount of stocks 8237
# 2020-08-03: Amount of stocks 8240
# 2020-08-04: Amount of stocks 8241
# 2020-08-05: Amount of stocks 8246
# 2020-08-06: Amount of stocks 8248
# 2020-08-07: Amount of stocks 8258
# 2020-08-10: Amount of stocks 8264
# 2020-08-11: Amount of stocks 8266
# 2020-08-12: Amount of stocks 8271
# 2020-08-13: Amount of stocks 8272
# 2020-08-14: Amount of stocks 8280
# 2020-08-17: Amount of stocks 8282
# 2020-08-18: Amount of stocks 8284
# 2020-08-19: Amount of stocks 8288
# 2020-08-20: Amount of stocks 8290
# 2020-08-21: Amount of stocks 8295
# 2020-08-24: Amount of stocks 8300
# 2020-08-25: Amount of stocks 8301
# 2020-08-26: Amount of stocks 8303
# 2020-08-27: Amount of stocks 8306
# 2020-08-28: Amount of stocks 8312
# 2020-08-31: Amount of stocks 8317
# 2020-09-01: Amount of stocks 8319
# 2020-09-02: Amount of stocks 8323
# 2020-09-03: Amount of stocks 8326
# 2020-09-04: Amount of stocks 8328
# 2020-09-08: Amount of stocks 8333
# 2020-09-09: Amount of stocks 8333
# 2020-09-10: Amount of stocks 8336
# 2020-09-11: Amount of stocks 8339
# 2020-09-14: Amount of stocks 8341
# 2020-09-15: Amount of stocks 8345
# 2020-09-16: Amount of stocks 8352
# 2020-09-17: Amount of stocks 8358
# 2020-09-18: Amount of stocks 8368
# 2020-09-21: Amount of stocks 8375
# 2020-09-22: Amount of stocks 8378
# 2020-09-23: Amount of stocks 8385
# 2020-09-24: Amount of stocks 8390
# 2020-09-25: Amount of stocks 8400
# 2020-09-28: Amount of stocks 8402
# 2020-09-29: Amount of stocks 8407
# 2020-09-30: Amount of stocks 8409
# 2020-10-01: Amount of stocks 8419
# 2020-10-02: Amount of stocks 8429
# 2020-10-05: Amount of stocks 8437
# 2020-10-06: Amount of stocks 8442
# 2020-10-07: Amount of stocks 8442
# 2020-10-08: Amount of stocks 8450
# 2020-10-09: Amount of stocks 8459
# 2020-10-12: Amount of stocks 8462
# 2020-10-13: Amount of stocks 8464
# 2020-10-14: Amount of stocks 8468
# 2020-10-15: Amount of stocks 8477
# 2020-10-16: Amount of stocks 8488
# 2020-10-19: Amount of stocks 8494
# 2020-10-20: Amount of stocks 8497
# 2020-10-21: Amount of stocks 8499
# 2020-10-22: Amount of stocks 8504
# 2020-10-23: Amount of stocks 8507
# 2020-10-26: Amount of stocks 8514
# 2020-10-27: Amount of stocks 8517
# 2020-10-28: Amount of stocks 8517
# 2020-10-29: Amount of stocks 8529
# 2020-10-30: Amount of stocks 8538
# 2020-11-02: Amount of stocks 8549
# 2020-11-03: Amount of stocks 8549
# 2020-11-04: Amount of stocks 8550
# 2020-11-05: Amount of stocks 8551
# 2020-11-06: Amount of stocks 8554
# 2020-11-09: Amount of stocks 8562
# 2020-11-10: Amount of stocks 8568
# 2020-11-11: Amount of stocks 8570
# 2020-11-12: Amount of stocks 8577
# 2020-11-13: Amount of stocks 8585
# 2020-11-16: Amount of stocks 8592
# 2020-11-17: Amount of stocks 8599
# 2020-11-18: Amount of stocks 8604
# 2020-11-19: Amount of stocks 8615
# 2020-11-20: Amount of stocks 8627
# 2020-11-23: Amount of stocks 8641
# 2020-11-24: Amount of stocks 8646
# 2020-11-25: Amount of stocks 8650
# 2020-11-27: Amount of stocks 8659
# 2020-11-30: Amount of stocks 8666
# 2020-12-01: Amount of stocks 8675
# 2020-12-02: Amount of stocks 8679
# 2020-12-03: Amount of stocks 8688
# 2020-12-04: Amount of stocks 8693
# 2020-12-07: Amount of stocks 8696
# 2020-12-08: Amount of stocks 8701
# 2020-12-09: Amount of stocks 8706
# 2020-12-10: Amount of stocks 8718
# 2020-12-11: Amount of stocks 8731
# 2020-12-14: Amount of stocks 8736
# 2020-12-15: Amount of stocks 8743
# 2020-12-16: Amount of stocks 8750
# 2020-12-17: Amount of stocks 8756
# 2020-12-18: Amount of stocks 8764
# 2020-12-21: Amount of stocks 8768
# 2020-12-22: Amount of stocks 8772
# 2020-12-23: Amount of stocks 8780
# 2020-12-24: Amount of stocks 8782
# 2020-12-28: Amount of stocks 8785
# 2020-12-29: Amount of stocks 8787
# 2020-12-30: Amount of stocks 8792
# 2020-12-31: Amount of stocks 8798
# 2021-01-04: Amount of stocks 8809
# 2021-01-05: Amount of stocks 8812
# 2021-01-06: Amount of stocks 8814
# 2021-01-07: Amount of stocks 8820
# 2021-01-08: Amount of stocks 8826
# 2021-01-11: Amount of stocks 8833
# 2021-01-12: Amount of stocks 8838
# 2021-01-13: Amount of stocks 8841
# 2021-01-14: Amount of stocks 8848
# 2021-01-15: Amount of stocks 8854
# 2021-01-19: Amount of stocks 8859
# 2021-01-20: Amount of stocks 8861
# 2021-01-21: Amount of stocks 8870
# 2021-01-22: Amount of stocks 8880
# 2021-01-25: Amount of stocks 8887
# 2021-01-26: Amount of stocks 8893
# 2021-01-27: Amount of stocks 8900
# 2021-01-28: Amount of stocks 8909
# 2021-01-29: Amount of stocks 8918
# 2021-02-01: Amount of stocks 8931
# 2021-02-02: Amount of stocks 8936
# 2021-02-03: Amount of stocks 8938
# 2021-02-04: Amount of stocks 8946
# 2021-02-05: Amount of stocks 8964
# 2021-02-08: Amount of stocks 8973
# 2021-02-09: Amount of stocks 8982
# 2021-02-10: Amount of stocks 8988
# 2021-02-11: Amount of stocks 8999
# 2021-02-12: Amount of stocks 9006
# 2021-02-16: Amount of stocks 9010
# 2021-02-17: Amount of stocks 9020
# 2021-02-18: Amount of stocks 9021
# 2021-02-19: Amount of stocks 9023
# 2021-02-22: Amount of stocks 9026
# 2021-02-23: Amount of stocks 9027
# 2021-02-24: Amount of stocks 9029
# 2021-02-25: Amount of stocks 9037
# 2021-02-26: Amount of stocks 9043
# 2021-03-01: Amount of stocks 9070
# 2021-03-02: Amount of stocks 9072
# 2021-03-03: Amount of stocks 9080
# 2021-03-04: Amount of stocks 9083
# 2021-03-05: Amount of stocks 9095
# 2021-03-08: Amount of stocks 9110
# 2021-03-09: Amount of stocks 9118
# 2021-03-10: Amount of stocks 9122
# 2021-03-11: Amount of stocks 9126
# 2021-03-12: Amount of stocks 9134
# 2021-03-15: Amount of stocks 9147
# 2021-03-16: Amount of stocks 9150
# 2021-03-17: Amount of stocks 9155
# 2021-03-18: Amount of stocks 9167
# 2021-03-19: Amount of stocks 9176
# 2021-03-22: Amount of stocks 9189
# 2021-03-23: Amount of stocks 9193
# 2021-03-24: Amount of stocks 9201
# 2021-03-25: Amount of stocks 9213
# 2021-03-26: Amount of stocks 9231
# 2021-03-29: Amount of stocks 9246
# 2021-03-30: Amount of stocks 9249
# 2021-03-31: Amount of stocks 9255
# 2021-04-01: Amount of stocks 9265
# 2021-04-05: Amount of stocks 9285
# 2021-04-06: Amount of stocks 9288
# 2021-04-07: Amount of stocks 9291
# 2021-04-08: Amount of stocks 9291
# 2021-04-09: Amount of stocks 9300
# 2021-04-12: Amount of stocks 9312
# 2021-04-13: Amount of stocks 9313
# 2021-04-14: Amount of stocks 9318
# 2021-04-15: Amount of stocks 9328
# 2021-04-16: Amount of stocks 9338
# 2021-04-19: Amount of stocks 9357
# 2021-04-20: Amount of stocks 9360
# 2021-04-21: Amount of stocks 9366
# 2021-04-22: Amount of stocks 9385
# 2021-04-23: Amount of stocks 9392
# 2021-04-26: Amount of stocks 9409
# 2021-04-27: Amount of stocks 9413
# 2021-04-28: Amount of stocks 9421
# 2021-04-29: Amount of stocks 9428
# 2021-04-30: Amount of stocks 9439
# 2021-05-03: Amount of stocks 9453
# 2021-05-04: Amount of stocks 9455
# 2021-05-05: Amount of stocks 9458
# 2021-05-06: Amount of stocks 9468
# 2021-05-07: Amount of stocks 9481
# 2021-05-10: Amount of stocks 9491
# 2021-05-11: Amount of stocks 9497
# 2021-05-12: Amount of stocks 9498
# 2021-05-13: Amount of stocks 9508
# 2021-05-14: Amount of stocks 9522
# 2021-05-17: Amount of stocks 9524
# 2021-05-18: Amount of stocks 9532
# 2021-05-19: Amount of stocks 9537
# 2021-05-20: Amount of stocks 9541
# 2021-05-21: Amount of stocks 9543
# 2021-05-24: Amount of stocks 9545
# 2021-05-25: Amount of stocks 9554
# 2021-05-26: Amount of stocks 9559
# 2021-05-27: Amount of stocks 9562
# 2021-05-28: Amount of stocks 9567
# 2021-06-01: Amount of stocks 9571
# 2021-06-02: Amount of stocks 9575
# 2021-06-03: Amount of stocks 9578
# 2021-06-04: Amount of stocks 9580
# 2021-06-07: Amount of stocks 9586
# 2021-06-08: Amount of stocks 9590
# 2021-06-09: Amount of stocks 9594
# 2021-06-10: Amount of stocks 9602
# 2021-06-11: Amount of stocks 9609
# 2021-06-14: Amount of stocks 9610
# 2021-06-15: Amount of stocks 9618
# 2021-06-16: Amount of stocks 9623
# 2021-06-17: Amount of stocks 9636
# 2021-06-18: Amount of stocks 9645
# 2021-06-21: Amount of stocks 9650
# 2021-06-22: Amount of stocks 9654
# 2021-06-23: Amount of stocks 9658
# 2021-06-24: Amount of stocks 9667
# 2021-06-25: Amount of stocks 9677
# 2021-06-28: Amount of stocks 9685
# 2021-06-29: Amount of stocks 9694
# 2021-06-30: Amount of stocks 9708
# 2021-07-01: Amount of stocks 9721
# 2021-07-02: Amount of stocks 9728
# 2021-07-06: Amount of stocks 9732
# 2021-07-07: Amount of stocks 9739
# 2021-07-08: Amount of stocks 9743
# 2021-07-09: Amount of stocks 9752
# 2021-07-12: Amount of stocks 9756
# 2021-07-13: Amount of stocks 9760
# 2021-07-14: Amount of stocks 9766
# 2021-07-15: Amount of stocks 9781
# 2021-07-16: Amount of stocks 9792
# 2021-07-19: Amount of stocks 9799
# 2021-07-20: Amount of stocks 9805
# 2021-07-21: Amount of stocks 9815
# 2021-07-22: Amount of stocks 9828
# 2021-07-23: Amount of stocks 9839
# 2021-07-26: Amount of stocks 9842
# 2021-07-27: Amount of stocks 9845
# 2021-07-28: Amount of stocks 9858
# 2021-07-29: Amount of stocks 9870
# 2021-07-30: Amount of stocks 9883
# 2021-08-02: Amount of stocks 9889
# 2021-08-03: Amount of stocks 9898
# 2021-08-04: Amount of stocks 9906
# 2021-08-05: Amount of stocks 9913
# 2021-08-06: Amount of stocks 9917
# 2021-08-09: Amount of stocks 9920
# 2021-08-10: Amount of stocks 9925
# 2021-08-11: Amount of stocks 9930
# 2021-08-12: Amount of stocks 9935
# 2021-08-13: Amount of stocks 9940
# 2021-08-16: Amount of stocks 9945
# 2021-08-17: Amount of stocks 9951
# 2021-08-18: Amount of stocks 9954
# 2021-08-19: Amount of stocks 9956
# 2021-08-20: Amount of stocks 9960
# 2021-08-23: Amount of stocks 9964
# 2021-08-24: Amount of stocks 9969
# 2021-08-25: Amount of stocks 9972
# 2021-08-26: Amount of stocks 9978
# 2021-08-27: Amount of stocks 9987
# 2021-08-30: Amount of stocks 9991
# 2021-08-31: Amount of stocks 9999
# 2021-09-01: Amount of stocks 10004
# 2021-09-02: Amount of stocks 10007
# 2021-09-03: Amount of stocks 10011
# 2021-09-07: Amount of stocks 10015
# 2021-09-08: Amount of stocks 10019
# 2021-09-09: Amount of stocks 10024
# 2021-09-10: Amount of stocks 10029
# 2021-09-13: Amount of stocks 10033
# 2021-09-14: Amount of stocks 10040
# 2021-09-15: Amount of stocks 10050
# 2021-09-16: Amount of stocks 10055
# 2021-09-17: Amount of stocks 10059
# 2021-09-20: Amount of stocks 10065
# 2021-09-21: Amount of stocks 10069
# 2021-09-22: Amount of stocks 10074
# 2021-09-23: Amount of stocks 10086
# 2021-09-24: Amount of stocks 10091
# 2021-09-27: Amount of stocks 10095
# 2021-09-28: Amount of stocks 10102
# 2021-09-29: Amount of stocks 10108
# 2021-09-30: Amount of stocks 10122
# 2021-10-01: Amount of stocks 10140
# 2021-10-04: Amount of stocks 10153
# 2021-10-05: Amount of stocks 10157
# 2021-10-06: Amount of stocks 10162
# 2021-10-07: Amount of stocks 10165
# 2021-10-08: Amount of stocks 10174
# 2021-10-11: Amount of stocks 10177
# 2021-10-12: Amount of stocks 10178
# 2021-10-13: Amount of stocks 10186
# 2021-10-14: Amount of stocks 10189
# 2021-10-15: Amount of stocks 10190
# 2021-10-18: Amount of stocks 10200
# 2021-10-19: Amount of stocks 10205
# 2021-10-20: Amount of stocks 10212
# 2021-10-21: Amount of stocks 10223
# 2021-10-22: Amount of stocks 10232
# 2021-10-25: Amount of stocks 10237
# 2021-10-26: Amount of stocks 10241
# 2021-10-27: Amount of stocks 10245
# 2021-10-28: Amount of stocks 10255
# 2021-10-29: Amount of stocks 10266
# 2021-11-01: Amount of stocks 10276
# 2021-11-02: Amount of stocks 10281
# 2021-11-03: Amount of stocks 10288
# 2021-11-04: Amount of stocks 10299
# 2021-11-05: Amount of stocks 10312
# 2021-11-08: Amount of stocks 10318
# 2021-11-09: Amount of stocks 10327
# 2021-11-10: Amount of stocks 10334
# 2021-11-11: Amount of stocks 10344
# 2021-11-12: Amount of stocks 10353
# 2021-11-15: Amount of stocks 10358
# 2021-11-16: Amount of stocks 10362
# 2021-11-17: Amount of stocks 10369
# 2021-11-18: Amount of stocks 10371
# 2021-11-19: Amount of stocks 10377
# 2021-11-22: Amount of stocks 10384
# 2021-11-23: Amount of stocks 10385
# 2021-11-24: Amount of stocks 10391
# 2021-11-26: Amount of stocks 10397
# 2021-11-29: Amount of stocks 10401
# 2021-11-30: Amount of stocks 10405
# 2021-12-01: Amount of stocks 10410
# 2021-12-02: Amount of stocks 10414
# 2021-12-03: Amount of stocks 10418
# 2021-12-06: Amount of stocks 10426
# 2021-12-07: Amount of stocks 10428
# 2021-12-08: Amount of stocks 10437
# 2021-12-09: Amount of stocks 10447
# 2021-12-10: Amount of stocks 10457
# 2021-12-13: Amount of stocks 10469
# 2021-12-14: Amount of stocks 10475
# 2021-12-15: Amount of stocks 10477
# 2021-12-16: Amount of stocks 10485
# 2021-12-17: Amount of stocks 10494
# 2021-12-20: Amount of stocks 10504
# 2021-12-21: Amount of stocks 10506
# 2021-12-22: Amount of stocks 10508
# 2021-12-23: Amount of stocks 10518
# 2021-12-27: Amount of stocks 10532
# 2021-12-28: Amount of stocks 10534
# 2021-12-29: Amount of stocks 10536
# 2021-12-30: Amount of stocks 10547
# 2021-12-31: Amount of stocks 10553
# 2022-01-03: Amount of stocks 10565
# 2022-01-04: Amount of stocks 10566
# 2022-01-05: Amount of stocks 10569
# 2022-01-06: Amount of stocks 10571
# 2022-01-07: Amount of stocks 10579
# 2022-01-10: Amount of stocks 10590
# 2022-01-11: Amount of stocks 10592
# 2022-01-12: Amount of stocks 10594
# 2022-01-13: Amount of stocks 10599
# 2022-01-14: Amount of stocks 10607
# 2022-01-18: Amount of stocks 10611
# 2022-01-19: Amount of stocks 10616
# 2022-01-20: Amount of stocks 10622
# 2022-01-21: Amount of stocks 10631
# 2022-01-24: Amount of stocks 10643
# 2022-01-25: Amount of stocks 10646
# 2022-01-26: Amount of stocks 10649
# 2022-01-27: Amount of stocks 10654
# 2022-01-28: Amount of stocks 10659
# 2022-01-31: Amount of stocks 10675
# 2022-02-01: Amount of stocks 10679
# 2022-02-02: Amount of stocks 10682
# 2022-02-03: Amount of stocks 10685
# 2022-02-04: Amount of stocks 10695
# 2022-02-07: Amount of stocks 10705
# 2022-02-08: Amount of stocks 11261
# 2022-02-09: Amount of stocks 11816
# 2022-02-10: Amount of stocks 11823
# 2022-02-11: Amount of stocks 11829
# 2022-02-14: Amount of stocks 11833
# 2022-02-15: Amount of stocks 11838
# 2022-02-16: Amount of stocks 11841
# 2022-02-17: Amount of stocks 11845
# 2022-02-18: Amount of stocks 11846
# 2022-02-22: Amount of stocks 11851
# 2022-02-23: Amount of stocks 11854
# 2022-02-24: Amount of stocks 11856
# 2022-02-25: Amount of stocks 11859
# 2022-02-28: Amount of stocks 11865
# 2022-03-01: Amount of stocks 11869
# 2022-03-02: Amount of stocks 11873
# 2022-03-03: Amount of stocks 11959
# 2022-03-04: Amount of stocks 12051
# 2022-03-07: Amount of stocks 12055
# 2022-03-08: Amount of stocks 12057
# 2022-03-09: Amount of stocks 12059
# 2022-03-10: Amount of stocks 12060
# 2022-03-11: Amount of stocks 12063
# 2022-03-14: Amount of stocks 12071
# 2022-03-15: Amount of stocks 12077
# 2022-03-16: Amount of stocks 12078
# 2022-03-17: Amount of stocks 12082
# 2022-03-18: Amount of stocks 12083
# 2022-03-21: Amount of stocks 12088
# 2022-03-22: Amount of stocks 12091
# 2022-03-23: Amount of stocks 12094
# 2022-03-24: Amount of stocks 12097
# 2022-03-25: Amount of stocks 12099
# 2022-03-28: Amount of stocks 12105
# 2022-03-29: Amount of stocks 12108
# 2022-03-30: Amount of stocks 12109
# 2022-03-31: Amount of stocks 12111
# 2022-04-01: Amount of stocks 12120
# 2022-04-04: Amount of stocks 12182
# 2022-04-05: Amount of stocks 12192
# 2022-04-06: Amount of stocks 12240
# 2022-04-07: Amount of stocks 12242
# 2022-04-08: Amount of stocks 12244
# 2022-04-11: Amount of stocks 12248
# 2022-04-12: Amount of stocks 12251
# 2022-04-13: Amount of stocks 12286
# 2022-04-14: Amount of stocks 12324
# 2022-04-18: Amount of stocks 12327
# 2022-04-19: Amount of stocks 12328
# 2022-04-20: Amount of stocks 12329
# 2022-04-21: Amount of stocks 12329
# 2022-04-22: Amount of stocks 12334
# 2022-04-25: Amount of stocks 12336
# 2022-04-26: Amount of stocks 12338
# 2022-04-27: Amount of stocks 12345
# 2022-04-28: Amount of stocks 12348
# 2022-04-29: Amount of stocks 12354
# 2022-05-02: Amount of stocks 12357
# 2022-05-03: Amount of stocks 12360
# 2022-05-04: Amount of stocks 12361
# 2022-05-05: Amount of stocks 12366
# 2022-05-06: Amount of stocks 12369
# 2022-05-09: Amount of stocks 12373
# 2022-05-10: Amount of stocks 12375
# 2022-05-11: Amount of stocks 12376
# 2022-05-12: Amount of stocks 12378
# 2022-05-13: Amount of stocks 12381
# 2022-05-16: Amount of stocks 12383
# 2022-05-17: Amount of stocks 12393
# 2022-05-18: Amount of stocks 12396
# 2022-05-19: Amount of stocks 12401
# 2022-05-20: Amount of stocks 12405
# 2022-05-23: Amount of stocks 12409
# 2022-05-24: Amount of stocks 12417
# 2022-05-25: Amount of stocks 12423
# 2022-05-26: Amount of stocks 12428
# 2022-05-27: Amount of stocks 12435
# 2022-05-31: Amount of stocks 12443
# 2022-06-01: Amount of stocks 12447
# 2022-06-02: Amount of stocks 12452
# 2022-06-03: Amount of stocks 12455
# 2022-06-06: Amount of stocks 12475
# 2022-06-07: Amount of stocks 12478
# 2022-06-08: Amount of stocks 12483
# 2022-06-09: Amount of stocks 12488
# 2022-06-10: Amount of stocks 12490
# 2022-06-13: Amount of stocks 12494
# 2022-06-14: Amount of stocks 12497
# 2022-06-15: Amount of stocks 12504
# 2022-06-16: Amount of stocks 12510
# 2022-06-17: Amount of stocks 12513
# 2022-06-21: Amount of stocks 12518
# 2022-06-22: Amount of stocks 12522
# 2022-06-23: Amount of stocks 12532
# 2022-06-24: Amount of stocks 12534
# 2022-06-27: Amount of stocks 12539
# 2022-06-28: Amount of stocks 12542
# 2022-06-29: Amount of stocks 12544
# 2022-06-30: Amount of stocks 12551
# 2022-07-01: Amount of stocks 12555
# 2022-07-05: Amount of stocks 12572
# 2022-07-06: Amount of stocks 12581
# 2022-07-07: Amount of stocks 12583
# 2022-07-08: Amount of stocks 12587
# 2022-07-11: Amount of stocks 12593
# 2022-07-12: Amount of stocks 12599
# 2022-07-13: Amount of stocks 12605
# 2022-07-14: Amount of stocks 12610
# 2022-07-15: Amount of stocks 12611
# 2022-07-18: Amount of stocks 12612
# 2022-07-19: Amount of stocks 12616
# 2022-07-20: Amount of stocks 12624
# 2022-07-21: Amount of stocks 12631
# 2022-07-22: Amount of stocks 12639
# 2022-07-25: Amount of stocks 12645
# 2022-07-26: Amount of stocks 12648
# 2022-07-27: Amount of stocks 12650
# 2022-07-28: Amount of stocks 12656
# 2022-07-29: Amount of stocks 12659
# 2022-08-01: Amount of stocks 12667
# 2022-08-02: Amount of stocks 12676
# 2022-08-03: Amount of stocks 12680
# 2022-08-04: Amount of stocks 12683
# 2022-08-05: Amount of stocks 12688
# 2022-08-08: Amount of stocks 12694
# 2022-08-09: Amount of stocks 12696
# 2022-08-10: Amount of stocks 12699
# 2022-08-11: Amount of stocks 12706
# 2022-08-12: Amount of stocks 12715
# 2022-08-15: Amount of stocks 12723
# 2022-08-16: Amount of stocks 12726
# 2022-08-17: Amount of stocks 12746
# 2022-08-18: Amount of stocks 12750
# 2022-08-19: Amount of stocks 12754
# 2022-08-22: Amount of stocks 13227
# 2022-08-23: Amount of stocks 13238
# 2022-08-24: Amount of stocks 13240
# 2022-08-25: Amount of stocks 13253
# 2022-08-26: Amount of stocks 13261
# 2022-08-29: Amount of stocks 13270
# 2022-08-30: Amount of stocks 13279
# 2022-08-31: Amount of stocks 13288
# 2022-09-01: Amount of stocks 13294
# 2022-09-02: Amount of stocks 13300
# 2022-09-06: Amount of stocks 13306
# 2022-09-07: Amount of stocks 13315
# 2022-09-08: Amount of stocks 13325
# 2022-09-09: Amount of stocks 13338
# 2022-09-12: Amount of stocks 13345
# 2022-09-13: Amount of stocks 13355
# 2022-09-14: Amount of stocks 13363
# 2022-09-15: Amount of stocks 13374
# 2022-09-16: Amount of stocks 13382
# 2022-09-19: Amount of stocks 13393
# 2022-09-20: Amount of stocks 13412
# 2022-09-21: Amount of stocks 13420
# 2022-09-22: Amount of stocks 13425
# 2022-09-23: Amount of stocks 13434
# 2022-09-26: Amount of stocks 13442
# 2022-09-27: Amount of stocks 13452
# 2022-09-28: Amount of stocks 13464
# 2022-09-29: Amount of stocks 13481
# 2022-09-30: Amount of stocks 13492
# 2022-10-03: Amount of stocks 13510
# 2022-10-04: Amount of stocks 13520
# 2022-10-05: Amount of stocks 13530
# 2022-10-06: Amount of stocks 13530
# 2022-10-07: Amount of stocks 13548
# 2022-10-10: Amount of stocks 13554
# 2022-10-11: Amount of stocks 13555
# 2022-10-12: Amount of stocks 13557
# 2022-10-13: Amount of stocks 13565
# 2022-10-14: Amount of stocks 13567
# 2022-10-17: Amount of stocks 13569
# 2022-10-18: Amount of stocks 13575
# 2022-10-19: Amount of stocks 13580
# 2022-10-20: Amount of stocks 13583
# 2022-10-21: Amount of stocks 13583
# 2022-10-24: Amount of stocks 13594
# 2022-10-25: Amount of stocks 13600
# 2022-10-26: Amount of stocks 13603
# 2022-10-27: Amount of stocks 13610
# 2022-10-28: Amount of stocks 13610
# 2022-10-31: Amount of stocks 13619
# 2022-11-01: Amount of stocks 13625
# 2022-11-02: Amount of stocks 13631
# 2022-11-03: Amount of stocks 13638
# 2022-11-04: Amount of stocks 13640
# 2022-11-07: Amount of stocks 13647
# 2022-11-08: Amount of stocks 13651
# 2022-11-09: Amount of stocks 13655
# 2022-11-10: Amount of stocks 13664
# 2022-11-11: Amount of stocks 13669
# 2022-11-14: Amount of stocks 13679
# 2022-11-15: Amount of stocks 13687
# 2022-11-16: Amount of stocks 13687
# 2022-11-17: Amount of stocks 13692
# 2022-11-18: Amount of stocks 13692
# 2022-11-21: Amount of stocks 13692
# 2022-11-22: Amount of stocks 13705
# 2022-11-23: Amount of stocks 13710
# 2022-11-25: Amount of stocks 13712
# 2022-11-28: Amount of stocks 13717
# 2022-11-29: Amount of stocks 13721
# 2022-11-30: Amount of stocks 13725
# 2022-12-01: Amount of stocks 13736
# 2022-12-02: Amount of stocks 13742
# 2022-12-05: Amount of stocks 13745
# 2022-12-06: Amount of stocks 13750
# 2022-12-07: Amount of stocks 13753
# 2022-12-08: Amount of stocks 13759
# 2022-12-09: Amount of stocks 13768
# 2022-12-12: Amount of stocks 13778
# 2022-12-13: Amount of stocks 13786
# 2022-12-14: Amount of stocks 13796
# 2022-12-15: Amount of stocks 13803
# 2022-12-16: Amount of stocks 13808
# 2022-12-19: Amount of stocks 13816
# 2022-12-20: Amount of stocks 13821
# 2022-12-21: Amount of stocks 13824
# 2022-12-22: Amount of stocks 13827
# 2022-12-23: Amount of stocks 13830
# 2022-12-27: Amount of stocks 13841
# 2022-12-28: Amount of stocks 13842
# 2022-12-29: Amount of stocks 13847
# 2022-12-30: Amount of stocks 13851
# 2023-01-03: Amount of stocks 13858
# 2023-01-04: Amount of stocks 13876
# 2023-01-05: Amount of stocks 13882
# 2023-01-06: Amount of stocks 13885
# 2023-01-09: Amount of stocks 13898
# 2023-01-10: Amount of stocks 13908
# 2023-01-11: Amount of stocks 13910
# 2023-01-12: Amount of stocks 13914
# 2023-01-13: Amount of stocks 13920
# 2023-01-17: Amount of stocks 13925
# 2023-01-18: Amount of stocks 13930
# 2023-01-19: Amount of stocks 13938
# 2023-01-20: Amount of stocks 13944
# 2023-01-23: Amount of stocks 13948
# 2023-01-24: Amount of stocks 13949
# 2023-01-25: Amount of stocks 13957
# 2023-01-26: Amount of stocks 13963
# 2023-01-27: Amount of stocks 13969
# 2023-01-30: Amount of stocks 13974
# 2023-01-31: Amount of stocks 13980
# 2023-02-01: Amount of stocks 13985
# 2023-02-02: Amount of stocks 13987
# 2023-02-03: Amount of stocks 13993
# 2023-02-06: Amount of stocks 13998
# 2023-02-07: Amount of stocks 14000
# 2023-02-08: Amount of stocks 14004
# 2023-02-09: Amount of stocks 14011
# 2023-02-10: Amount of stocks 14017
# 2023-02-13: Amount of stocks 14019
# 2023-02-14: Amount of stocks 14025
# 2023-02-15: Amount of stocks 14032
# 2023-02-16: Amount of stocks 14034
# 2023-02-17: Amount of stocks 14036
# 2023-02-21: Amount of stocks 14044
# 2023-02-22: Amount of stocks 14048
# 2023-02-23: Amount of stocks 14052
# 2023-02-24: Amount of stocks 14056
# 2023-02-27: Amount of stocks 14061
# 2023-02-28: Amount of stocks 14071
# 2023-03-01: Amount of stocks 14077
# 2023-03-02: Amount of stocks 14081
# 2023-03-03: Amount of stocks 14082
# 2023-03-06: Amount of stocks 14085
# 2023-03-07: Amount of stocks 14090
# 2023-03-08: Amount of stocks 14096
# 2023-03-09: Amount of stocks 14100
# 2023-03-10: Amount of stocks 14105
# 2023-03-13: Amount of stocks 14109
# 2023-03-14: Amount of stocks 14113
# 2023-03-15: Amount of stocks 14119
# 2023-03-16: Amount of stocks 14127
# 2023-03-17: Amount of stocks 14135
# 2023-03-20: Amount of stocks 14137
# 2023-03-21: Amount of stocks 14143
# 2023-03-22: Amount of stocks 14149
# 2023-03-23: Amount of stocks 14156
# 2023-03-24: Amount of stocks 14161
# 2023-03-27: Amount of stocks 14165
# 2023-03-28: Amount of stocks 14171
# 2023-03-29: Amount of stocks 14176
# 2023-03-30: Amount of stocks 14184
# 2023-03-31: Amount of stocks 14198
# 2023-04-03: Amount of stocks 14207
# 2023-04-04: Amount of stocks 14214
# 2023-04-05: Amount of stocks 14217
# 2023-04-06: Amount of stocks 14220
# 2023-04-10: Amount of stocks 14222
# 2023-04-11: Amount of stocks 14225
# 2023-04-12: Amount of stocks 14227
# 2023-04-13: Amount of stocks 14231
# 2023-04-14: Amount of stocks 14234
# 2023-04-17: Amount of stocks 14240
# 2023-04-18: Amount of stocks 14245
# 2023-04-19: Amount of stocks 14248
# 2023-04-20: Amount of stocks 14252
# 2023-04-21: Amount of stocks 14257
# 2023-04-24: Amount of stocks 14261
# 2023-04-25: Amount of stocks 14267
# 2023-04-26: Amount of stocks 14272
# 2023-04-27: Amount of stocks 14275
# 2023-04-28: Amount of stocks 14278
# 2023-05-01: Amount of stocks 14282
# 2023-05-02: Amount of stocks 14286
# 2023-05-03: Amount of stocks 14289
# 2023-05-04: Amount of stocks 14294
# 2023-05-05: Amount of stocks 14297
# 2023-05-08: Amount of stocks 14370
# 2023-05-09: Amount of stocks 14374
# 2023-05-10: Amount of stocks 14375
# 2023-05-11: Amount of stocks 14378
# 2023-05-12: Amount of stocks 14381
# 2023-05-15: Amount of stocks 14388
# 2023-05-16: Amount of stocks 14390
# 2023-05-17: Amount of stocks 14393
# 2023-05-18: Amount of stocks 14395
# 2023-05-19: Amount of stocks 14398
# 2023-05-22: Amount of stocks 14404
# 2023-05-23: Amount of stocks 14413
# 2023-05-24: Amount of stocks 14428
# 2023-05-25: Amount of stocks 14435
# 2023-05-26: Amount of stocks 14442
# 2023-05-30: Amount of stocks 14447
# 2023-05-31: Amount of stocks 14451
# 2023-06-01: Amount of stocks 14459
# 2023-06-02: Amount of stocks 14464
# 2023-06-05: Amount of stocks 14467
# 2023-06-06: Amount of stocks 14467
# 2023-06-07: Amount of stocks 14471
# 2023-06-08: Amount of stocks 14475
# 2023-06-09: Amount of stocks 14478
# 2023-06-12: Amount of stocks 14491
# 2023-06-13: Amount of stocks 14495
# 2023-06-14: Amount of stocks 14500
# 2023-06-15: Amount of stocks 14506
# 2023-06-16: Amount of stocks 14516
# 2023-06-20: Amount of stocks 14522
# 2023-06-21: Amount of stocks 14529
# 2023-06-22: Amount of stocks 14534
# 2023-06-23: Amount of stocks 14540
# 2023-06-26: Amount of stocks 14544
# 2023-06-27: Amount of stocks 14546
# 2023-06-28: Amount of stocks 14555
# 2023-06-29: Amount of stocks 14559
# 2023-06-30: Amount of stocks 14564
# 2023-07-03: Amount of stocks 14569
# 2023-07-05: Amount of stocks 14579
# 2023-07-06: Amount of stocks 14587
# 2023-07-07: Amount of stocks 14589
# 2023-07-10: Amount of stocks 14590
# 2023-07-11: Amount of stocks 14593
# 2023-07-12: Amount of stocks 14596
# 2023-07-13: Amount of stocks 14598
# 2023-07-14: Amount of stocks 14606
# 2023-07-17: Amount of stocks 14611
# 2023-07-18: Amount of stocks 14616
# 2023-07-19: Amount of stocks 14621
# 2023-07-20: Amount of stocks 14624
# 2023-07-21: Amount of stocks 14628
# 2023-07-24: Amount of stocks 14633
# 2023-07-25: Amount of stocks 14639
# 2023-07-26: Amount of stocks 14643
# 2023-07-27: Amount of stocks 14647
# 2023-07-28: Amount of stocks 14648
# 2023-07-31: Amount of stocks 14653
# 2023-08-01: Amount of stocks 14663
# 2023-08-02: Amount of stocks 14666
# 2023-08-03: Amount of stocks 14673
# 2023-08-04: Amount of stocks 14688
# 2023-08-07: Amount of stocks 14691
# 2023-08-08: Amount of stocks 14697
# 2023-08-09: Amount of stocks 14698
# 2023-08-10: Amount of stocks 14701
# 2023-08-11: Amount of stocks 14703
# 2023-08-14: Amount of stocks 14707
# 2023-08-15: Amount of stocks 14714
# 2023-08-16: Amount of stocks 14717
# 2023-08-17: Amount of stocks 14724
# 2023-08-18: Amount of stocks 14724
# 2023-08-21: Amount of stocks 14737
# 2023-08-22: Amount of stocks 14742
# 2023-08-23: Amount of stocks 14748
# 2023-08-24: Amount of stocks 14752
# 2023-08-25: Amount of stocks 14754
# 2023-08-28: Amount of stocks 14761
# 2023-08-29: Amount of stocks 14767
# 2023-08-30: Amount of stocks 14771
# 2023-08-31: Amount of stocks 14776
# 2023-09-01: Amount of stocks 14779

# %% [markdown]
# We also create a function to retrieve the ticker list.

# %%
def get_tickers(v=5):
    """
    Retrieve the ticker list. Default is 5.
    """
    tickers = pd.read_csv(
        f"../data/tickers_v{v}.csv",
        parse_dates=["start_date", "end_date"],
        index_col=0,
        keep_default_na=False,
        na_values=["#N/A","#N/AN/A","#NA","-1.#IND","-1.#QNAN","-NaN","-nan","1.#IND","1.#QNAN","<NA>","N/A","NULL","NaN","None","n/a","nan","null",],
    )
    tickers["start_date"] = pd.to_datetime(tickers["start_date"]).dt.date
    tickers["end_date"] = pd.to_datetime(tickers["end_date"]).dt.date

    # This will only be applied in future notebooks.
    if tickers.columns.isin(["start_data", "end_data"]).any():
        tickers["start_data"] = pd.to_datetime(tickers["start_data"]).dt.date
        tickers["end_data"] = pd.to_datetime(tickers["end_data"]).dt.date

    # For some reason the cik is always interpreted as a string.
    tickers["cik"] = tickers["cik"].apply(
        lambda str: float(str) if len(str) != 0 else np.nan
    )
    return tickers

# %%
tickers_v1 = get_tickers(1)
tickers_v1[tickers_v1["ticker"] == "FB"]
# Out:
#      ticker                                       name  active  start_date  \
# 5037     FB                     Facebook, Inc. Class A   False  2019-01-01
# 5038     FB  Meta Platforms, Inc. Class A Common Stock   False  2021-11-01
#
#         end_date type        cik composite_figi
# 5037  2021-10-29   CS  1326801.0   BBG000MM2P62
# 5038  2022-06-08   CS  1326801.0   BBG000MM2P62

# %%
tickers_v1[tickers_v1["ticker"] == "META"]
# Out:
#      ticker                                       name  active  start_date  \
# 8462   META  Meta Platforms, Inc. Class A Common Stock    True  2022-06-09
#
#         end_date type        cik composite_figi
# 8462  2023-09-01   CS  1326801.0   BBG000MM2P62

# %%
print(len(tickers_v1))
# Out:
# 14779

# %% [markdown]
# # 3.4 Checks
#
# 1. Are SPACs handled correctly? We should expect that when they IPO a company, that they get delisted. Then one day after the delisting the new-born company should be listed. We will take a look at VFS. On 2023-8-15 it was IPO'd by the SPAC named BSAQ. So we should expect the delisting date of BSAQ to be 2023-8-14.

# %%
tickers_v1[tickers_v1["ticker"] == "VFS"]
# Out:
#       ticker                               name  active  start_date  \
# 13875    VFS  VinFast Auto Ltd. Ordinary Shares    True  2023-08-15
#
#          end_date type        cik composite_figi
# 13875  2023-09-01   CS  1913510.0

# %%
tickers_v1[tickers_v1["ticker"] == "BSAQ"]
# Out:
#      ticker                        name  active  start_date    end_date type  \
# 2075   BSAQ  Black Spade Acquisition Co   False  2021-09-07  2023-08-14   CS
#
#             cik composite_figi
# 2075  1851908.0

# %% [markdown]
# 2. Let's check SVB which went bankrupt and HTZ which went from OTC to listed.

# %%
tickers_v1[tickers_v1["ticker"] == "SIVB"]
# Out:
#       ticker                 name  active  start_date    end_date type  \
# 12081   SIVB  SVB Financial Group   False  2019-01-01  2023-03-27   CS
#
#             cik composite_figi
# 12081  719739.0   BBG000BT0CM2

# %%
tickers_v1[tickers_v1["ticker"] == "HTZ"]
# Out:
#      ticker                                     name  active  start_date  \
# 6688    HTZ              Hertz Global Holdings, Inc.   False  2019-01-01
# 6689    HTZ  Hertz Global Holdings, Inc Common Stock    True  2021-11-09
#
#         end_date type        cik composite_figi
# 6688  2020-10-29   CS  1657853.0   BBG00D5SHJH6
# 6689  2023-09-01   CS  1657853.0   BBG011N57109

# %% [markdown]
# 3. Sometimes tickers are re-used (e.g. META, but since it was an ETF it will not show up in our ticker list). Let's see if that has happened in our ticker list.

# %%
duplicated = tickers_v1[tickers_v1["ticker"].duplicated(keep=False)]
print(len(duplicated["ticker"].unique()))
print(len(duplicated))
duplicated.head()
# Out:
# 3339
# 9039
#   ticker                       name  active  start_date    end_date type  \
# 0      A       Agilent Technologies   False  2019-01-01  2019-08-16   CS
# 1      A  Agilent Technologies Inc.   False  2019-08-19  2022-02-07   CS
# 2      A  Agilent Technologies Inc.   False  2022-02-08  2022-02-08   CS
# 3      A  Agilent Technologies Inc.    True  2022-02-09  2023-09-01   CS
# 6    AAC         AAC Holdings, Inc.   False  2019-01-01  2019-10-25   CS
#
#          cik composite_figi
# 0  1090872.0   BBG000C2V3D6
# 1  1090872.0   BBG000C2V3D6
# 2  1090872.0   BBG000BWQYZ5
# 3  1090872.0   BBG000C2V3D6
# 6  1606180.0   BBG00K1Y3PT9

# %% [markdown]
# We will have some merging to do. However these are the "clean" ones. The next ones are just ridiculous and should not exist in the first place.

# %%
from collections import Counter
print(Counter(duplicated["ticker"].values.tolist()).most_common(5))
duplicated[duplicated["ticker"] == "DGICA"].head(5)
# ???
# Out:
# [('CMS', 162), ('PRE', 148), ('EP', 111), ('CRESY', 24), ('DGICA', 18)]
#      ticker               name  active  start_date    end_date type       cik  \
# 3875  DGICA  Donegal Group Inc   False  2019-01-01  2022-08-25   CS  800457.0
# 3876  DGICA  Donegal Group Inc   False  2022-08-26  2022-08-26   CS  948046.0
# 3877  DGICA  Donegal Group Inc   False  2022-08-29  2022-09-02   CS  800457.0
# 3878  DGICA  Donegal Group Inc   False  2022-09-06  2022-09-06   CS  948046.0
# 3879  DGICA  Donegal Group Inc   False  2022-09-07  2022-09-07   CS  800457.0
#
#      composite_figi
# 3875   BBG000JQJC22
# 3876   BBG000JQJC22
# 3877   BBG000JQJC22
# 3878   BBG000JQJC22
# 3879   BBG000JQJC22

# %%
duplicated[duplicated["ticker"] == "DISCK"].head(5)
# Out:
#      ticker                                   name  active  start_date  \
# 3951  DISCK  Discovery, Inc. Series C Common Stock   False  2019-01-01
# 3952  DISCK  Discovery, Inc. Series C Common Stock   False  2022-02-08
# 3953  DISCK  Discovery, Inc. Series C Common Stock   False  2022-02-09
# 3954  DISCK  Discovery, Inc. Series C Common Stock   False  2022-03-03
# 3955  DISCK  Discovery, Inc. Series C Common Stock   False  2022-03-04
#
#         end_date type        cik composite_figi
# 3951  2022-02-07   CS  1024333.0
# 3952  2022-02-08   CS  1024333.0   BBG000VMWHH5
# 3953  2022-03-02   CS  1024333.0
# 3954  2022-03-03   CS  1024333.0   BBG000VMWHH5
# 3955  2022-04-01   CS  1024333.0

# %% [markdown]
# On average there are 3.3 duplicates for duplicated tickers. When we take a look it seems that it happens a lot that the name/cik/composite_figi gets changed, even though it is the same company and ticker. For example for ZWS the name is "Zurn Water Solutions Corporation" on 2022-07-01 but on the next trading day (4th July was a stock holiday) the name changes to "Zurn Elkay Water Solutions Corporation".

# %% [markdown]
# # 3.5 Merging duplicates
# The most straightforward way to merge these duplicates is to see for every duplicate whether the the end_date (1st occurence) and start_date (2nd occurence) are consecutive *trading days*.

# %%
tickers_v1.head(3)
# Out:
#   ticker                       name  active  start_date    end_date type  \
# 0      A       Agilent Technologies   False  2019-01-01  2019-08-16   CS
# 1      A  Agilent Technologies Inc.   False  2019-08-19  2022-02-07   CS
# 2      A  Agilent Technologies Inc.   False  2022-02-08  2022-02-08   CS
#
#          cik composite_figi
# 0  1090872.0   BBG000C2V3D6
# 1  1090872.0   BBG000C2V3D6
# 2  1090872.0   BBG000BWQYZ5

# %% [markdown]
# First we need to get the duplicates.

# %%
###
tickers_v1 = get_tickers(1)
market_days = get_market_dates()

duplicated = tickers_v1[tickers_v1["ticker"].duplicated(keep=False)]

# Step 1: Get the indices of the rows that should be merged.
indices_duplicated = [] # looks like [['A', {1, 2, 3}], ['A', {4, 5}], ['B', {10, 11, 12, 13}]]
prev_index_and_row = None
prev_is_duplicate_and_back_to_back = False

for index, row in duplicated.iterrows():
    # Get attributes of previous ticker
    if prev_index_and_row is not None:
        prev_index = prev_index_and_row[0]
        prev_row = prev_index_and_row[1]
        prev_ticker = prev_row["ticker"]
        prev_name = prev_row["name"]
        prev_start_date = prev_row["start_date"]
        prev_end_date = prev_row["end_date"]
        prev_cik = prev_row["cik"]
        prev_figi = prev_row["composite_figi"]

    # Get attributes of current ticker
    current_index = index
    current_row = row
    current_ticker = current_row["ticker"]
    current_name = current_row["name"]
    current_start_date = current_row["start_date"]
    current_end_date = current_row["end_date"]
    current_cik = current_row["cik"]
    current_figi = current_row["composite_figi"]
    
    # Skip first index
    if prev_index_and_row is None:
        pass
    # Check if ticker duplicated and back-to-back
    elif prev_ticker == current_ticker and market_days[market_days.index(prev_end_date) + 1] == current_start_date:
        # New stock. Add stock and indices.
        if prev_is_duplicate_and_back_to_back == False:
            indices_duplicated.append([current_ticker, {prev_index, current_index}])
        # Stock already exists in indices_duplicated. Simply add indices.
        else:
            indices_duplicated[-1][-1].add(prev_index)
            indices_duplicated[-1][-1].add(current_index)
        
        # Update flag
        prev_is_duplicate_and_back_to_back = True
    else:
        prev_is_duplicate_and_back_to_back = False

    # Update prev_index_and_row for next iteration
    prev_index_and_row = (current_index, row)

# %%
print(len(indices_duplicated))
print(indices_duplicated[:3])
# Out:
# 2918
# [['A', {0, 1, 2, 3}], ['AADI', {12, 13}], ['AAN', {18, 19, 20, 21, 22}]]

# %% [markdown]
# Very rarely, it happens that the same ticker, but not the same company, has duplicates. E.g. if in our ticker list the first 5 rows is the ticker AAA, but the start and end dates are (1, 2), (2, 3), (3, 4), (9, 10), (10, 11), this means that these are two different companies. Then indices_duplicated contains ['AAA', {1, 2, 3, 4}] and ['AAA, {10, 11}]. If it *is* the same company, it managed to get delisted to OTC and revive to get their listing back. Or something is wrong with Polygons data.

# %%
# See which tickers are duplicated in indices_duplicated.
tickers_duplicates = set() 
for ticker, indices in indices_duplicated:
    if ticker in tickers_duplicates:
        print(ticker)
    tickers_duplicates.add(ticker)
# Out:
# CBL
# CVU
# FI
# HIVE
# NE
# NXU
# OBE
# SDRL

# %% [markdown]
# Now that we have a list of indices of the duplicated tickers, we can merge them together. We do this by looping over <code>indices_duplicated</code> and then changing all duplicated rows to get the correct values. Then we remove the duplicates.

# %%
###

# Step 2: Merge duplicated in tickers_all
"""
Which value is assigned:
    name: last
    active: last
    start_date: first
    end_date: last
    type: last (but does not matter as it is always CS or ADRC)
    cik: last value that is not NaN
    compositite_figi: last value that is not NaN
"""
for ticker, indices in indices_duplicated:
    # CAUTION: Make sure that indices is sorted! Else it can happen that end_date is before start_date. I only found this out later. Moral: Always do sanity checks.
    indices = sorted(list(indices))
    ticker_data_in_tickers_v1 = tickers_v1.iloc[indices, :]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("name")] = ticker_data_in_tickers_v1["name"].values[-1]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("active")] = ticker_data_in_tickers_v1["active"].values[-1]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("start_date")] = ticker_data_in_tickers_v1["start_date"].values[0]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("end_date")] = ticker_data_in_tickers_v1["end_date"].values[-1]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("type")] = ticker_data_in_tickers_v1["type"].values[-1]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("cik")] = ticker_data_in_tickers_v1["cik"].ffill().values[-1]
    tickers_v1.iloc[indices, tickers_v1.columns.get_loc("composite_figi")] = ticker_data_in_tickers_v1["composite_figi"].ffill().values[-1]

tickers_v1 = tickers_v1.drop_duplicates().reset_index(drop=True)

# %%
len(tickers_v1)
# Out:
# 9697

# %% [markdown]
# Now only a fraction of the original duplicated tickers remain.

# %%
duplicated = tickers_v1[tickers_v1["ticker"].duplicated(keep=False)]
print(len(duplicated["ticker"].unique()))
pd.set_option('display.max_rows', None)

duplicated.head(5)
# Out:
# 593
#    ticker                                               name  active  \
# 3     AAC                                 AAC Holdings, Inc.   False
# 4     AAC                       Ares Acquisition Corporation    True
# 57   ACAC     Acies Acquisition Corp. Class A Ordinary Share   False
# 58   ACAC  Acri Capital Acquisition Corporation Class A C...    True
# 74   ACET                                         Aceto Corp   False
#
#     start_date    end_date type        cik composite_figi
# 3   2019-01-01  2019-10-25   CS  1606180.0   BBG00K1Y3PT9
# 4   2021-03-25  2023-09-01   CS  1829432.0
# 57  2020-12-11  2021-06-21   CS  1823878.0
# 58  2022-08-01  2023-09-01   CS  1914023.0   BBG0160DYSM3
# 74  2019-01-01  2019-04-02   CS     2034.0   BBG00D8FFF27

# %% [markdown]
# We can see that some are the same company but not back-to-back. Some are different companies or went OTC and back, these are correct. However, for a lot of stocks, the first occurence only trades for a few days. That makes no sense. If you try to download data for these dates, you will see that there exists none.
#
# So some stocks have a 'ghost' day just before their IPO. E.g. YGF was IPO'd on 2023-03-28. But on 2023-03-24 had a entry with start_date and end_date of just one day. This is the same with VCIG, which had 2 'ghost' days on 2023-03-22 and 2023-04-06. For SXTP, the ghost days were actually two. Investigating the stocks that only have 1 day in our ticker list also shows funds (that are NOT common stocks!).
#
# Nevertheless, if start_date is equal to end_date, it's always unusable and something is wrong. So we will first remove all tickers that only exist for one day.

# %%
ghost_days = tickers_v1[(tickers_v1["end_date"] - tickers_v1["start_date"]) == timedelta(days=0)]
print(len(ghost_days))
ghost_days.head(5)
# Out:
# 534
#     ticker                                          name  active  start_date  \
# 93    ACLL                      ACell, Inc. Common Stock   False  2020-07-17
# 105    ACP           abrdn Income Credit Strategies Fund   False  2022-08-22
# 115    ACT             Enact Holdings, Inc. Common Stock   False  2021-05-13
# 123    ACV  Virtus Diversified Income & Convertible Fund   False  2022-08-22
# 132   ADCT                           ADC Therapeutics SA   False  2019-10-02
#
#        end_date type        cik composite_figi
# 93   2020-07-17   CS        NaN
# 105  2022-08-22   CS  1503290.0   BBG0017VSC04
# 115  2021-05-13   CS  1823529.0   BBG00WSNP4R3
# 123  2022-08-22   CS  1636289.0   BBG008HMBD22
# 132  2019-10-02   CS  1771910.0

# %%
###

# Only keep tickers that have >1 day history. But if they were just listed, keep them anyways.
tickers_v1 = tickers_v1[((tickers_v1["end_date"] - tickers_v1["start_date"]) > timedelta(days=0)) | 
                        (tickers_v1["end_date"] == market_days[market_days.index(END_DATE) - 1])]
len(tickers_v1)
# Out:
# 9163

# %% [markdown]
# The remaining duplicates are:

# %%
duplicated = tickers_v1[tickers_v1["ticker"].duplicated(keep=False)]
print(len(duplicated["ticker"].unique()))

duplicated.head(5)
# Out:
# 175
#    ticker                                               name  active  \
# 3     AAC                                 AAC Holdings, Inc.   False
# 4     AAC                       Ares Acquisition Corporation    True
# 57   ACAC     Acies Acquisition Corp. Class A Ordinary Share   False
# 58   ACAC  Acri Capital Acquisition Corporation Class A C...    True
# 74   ACET                                         Aceto Corp   False
#
#     start_date    end_date type        cik composite_figi
# 3   2019-01-01  2019-10-25   CS  1606180.0   BBG00K1Y3PT9
# 4   2021-03-25  2023-09-01   CS  1829432.0
# 57  2020-12-11  2021-06-21   CS  1823878.0
# 58  2022-08-01  2023-09-01   CS  1914023.0   BBG0160DYSM3
# 74  2019-01-01  2019-04-02   CS     2034.0   BBG00D8FFF27

# %% [markdown]
# We need to keep in mind that the <code>start_date</code> and <code>end_date</code> may not be the start/end dates of the data. To determine the data dates, we need to loop through the ticker list and see whether the data exists.
#
# However, after we have downloaded our data, we can just infer it. So we will postpone this to avoid doing it twice.

# %% [markdown]
# # 3.6 Removing incorrect classes
# There are still some weird or incorrect stock classes that we have to remove. These were found by just looking through the ticker list.
#
# These are:
# - Funds
# - Preferred stock/bonds
# - A "w" appended to the stock ticker
# - "Ex-distribution" or "When-issued" conditions

# %%
###
funds = tickers_v1[tickers_v1['name'].apply(lambda s: "Fund" in s.split())]
print(len(funds))
funds.head(3)
# Out:
# 144
#     ticker                                   name  active  start_date  \
# 122    ACV       AllianzGI Div Inc & Convert Fund   False  2019-04-02
# 171    ADX          Adams Diversified Equity Fund   False  2019-04-02
# 227    AFT  Apollo Senior Floating Rate Fund Inc.   False  2019-04-02
#
#        end_date type        cik composite_figi
# 122  2019-08-14   CS  1636289.0
# 171  2019-08-09   CS     2230.0   BBG000BB8MR6
# 227  2019-09-05   CS  1502573.0   BBG00174L007

# %%
###
notes = tickers_v1[tickers_v1['name'].str.contains('%')]
print(len(notes))
notes.head(3)
# Out:
# 52
#     ticker                                               name  active  \
# 78   ACGLN  Arch Capital Group Ltd. Depositary Shares, eac...    True
# 256  AGNCL  AGNC Investment Corp. Depositary Shares Each R...    True
# 257  AGNCO  AGNC Investment Corp. Depositary Shares, each ...    True
#
#      start_date    end_date type        cik composite_figi
# 78   2023-05-08  2023-09-07   CS   947484.0
# 256  2023-05-08  2023-09-07   CS  1423689.0
# 257  2023-05-08  2023-09-07   CS  1423689.0

# %%
###
tickers_w = tickers_v1[tickers_v1["ticker"].str.contains("w")]
print(len(tickers_w))
tickers_w.head(3)
# Out:
# 114
#     ticker                               name  active  start_date    end_date  \
# 15    AANw         The Aaron''s Company, Inc.   False  2020-11-25  2020-11-30
# 162   ADSw  Alliance Data Systems Corporation   False  2021-11-01  2021-11-05
# 302  AIRCw        Apartment Income REIT Corp.   False  2020-12-03  2020-12-14
#
#     type        cik composite_figi
# 15    CS  1821393.0   BBG00WCNDCZ6
# 162   CS  1101215.0
# 302   CS  1820877.0   BBG00XK3WVD0

# %%
###
when_issued_or_ex_distr = tickers_v1[tickers_v1['name'].apply(lambda s: ("When" in s.split()) or ("Issued" in s.split()) or ("When-Issued" in s.split()) or ("Ex-Distribution" in s.split())  )  ]
print(len(when_issued_or_ex_distr))
when_issued_or_ex_distr.head(3)
# Out:
# 71
#     ticker                                               name  active  \
# 136  ADEAV  Adeia Inc. Common Stock Ex-distribution When I...   False
# 534  AOUTV  American Outdoor Brands, Inc. Common Stock Whe...   False
# 955  BBIGV   Vinco Ventures, Inc. Ex-Distribution When-Issued   False
#
#      start_date    end_date type        cik composite_figi
# 136  2022-09-20  2022-09-30   CS        NaN   BBG019KN8702
# 534  2020-08-10  2020-08-24   CS  1808997.0   BBG00QV8FS02
# 955  2022-05-17  2022-06-29   CS  1717556.0   BBG0179FCVS8

# %%
###
wd_suffix = tickers_v1[tickers_v1["ticker"].str.contains("\.WD")]
print(len(wd_suffix))
wd_suffix.head(3)
# Out:
# 8
#       ticker                                  name  active  start_date  \
# 2406   DD.WD                DuPont de Nemours, Inc   False  2021-02-02
# 2473  DHR.WD  Danaher Corporation When Distributed   False  2019-12-16
# 2720  ECL.WD                           Ecolab Inc.   False  2020-06-03
#
#         end_date type        cik composite_figi
# 2406  2021-02-03   CS  1666700.0   BBG00BN961G4
# 2473  2019-12-18   CS   313616.0   BBG000BH3JF8
# 2720  2020-06-05   CS    31462.0   BBG000BHKYH4

# %%
###
indices_to_remove = funds.index.union(notes.index).union(tickers_w.index).union(when_issued_or_ex_distr.index).union(wd_suffix.index)

# %%
###
print(len(tickers_v1))
tickers_v1 = tickers_v1.drop(index=indices_to_remove)
print(len(tickers_v1))
# Out:
# 9163
# 8775

# %% [markdown]
# Apparently this is not enough. There are still a lot of misclassified funds/preferred stocks. For example the ticker ARDC (ARES DYNAMIC CREDIT ALLOCATION FUND, INC.) is considered a common stock on 2019-04-02. However on 2019-04-01 it is considered a fund. It seems that Polygon uses the filings to determine the classification, and that common stocks are the default class. Then sometimes the filings are incomplete and Polygon classifies it as a common stock.

# %%
funds = tickers_v1[tickers_v1["name"].str.lower().str.contains("fund") | tickers_v1["name"].str.lower().str.contains("strategies")]
print(len(funds))
funds.head(5)
# Out:
# 46
#      ticker                                               name  active  \
# 104     ACP                     Aberdeen Income Crd Strategies   False
# 618    ARDC          ARES DYNAMIC CREDIT ALLOCATION FUND, INC.   False
# 685    ASFI                                   Asta Funding Inc   False
# 1079    BGB             BLACKSTONE / GSO STRATEGIC CREDIT FUND   False
# 2389    DCF  BNY Mellon Alcentra Global Credit Income 2024 ...   False
#
#       start_date    end_date type        cik composite_figi               ID
# 104   2019-04-02  2019-08-09   CS  1503290.0   BBG0017VSC04   ACP-2019-04-02
# 618   2019-04-02  2019-09-05   CS  1515324.0   BBG001LJH325  ARDC-2019-04-02
# 685   2019-01-01  2020-09-29   CS  1001258.0   BBG00K9VT498  ASFI-2019-01-01
# 1079  2019-04-02  2019-09-09   CS  1546429.0   BBG002W5R785   BGB-2019-04-02
# 2389  2019-04-02  2019-09-09   CS  1627854.0   BBG00J2DVN20   DCF-2019-04-02

# %%
client.get_ticker_details(ticker="BGIO", date = "2019-09-13").type
# Out:
# 'FUND'

# %%
client.get_ticker_details(ticker="ACP", date = "2019-04-02").type
# Out:
# 'CS'

# %%
client.get_ticker_details(ticker="ACP", date = "2019-04-01").type
# Out:
# 'FUND'

# %% [markdown]
# We will solve this issue by looking at the classification for 4 days before or after the start/end date. If it is not a common stock, we will delete it from the ticker list.
#
# (It would be better to just use the next/last trading date, however this will give 'out of bounds' if this date is not in the list of market dates).

# %%
###
tickers_v1["ID"] = tickers_v1["ticker"] + '-' + tickers_v1["start_date"].astype(str)

# %%
### (OPTIONAL)
IDs_to_remove = []
for index, row in tickers_v1.copy().iterrows():
    try:
        # The get_ticker_details is extremely slow.
        day_before_start = row['start_date'] - timedelta(days=4) # To take care of weekends & holidays.
        type_before_start = client.get_ticker_details(ticker=row['ticker'], date = day_before_start).type
    except Exception as e:
        type_before_start = 'CS'

    try: 
        day_after_end = row['end_date'] + timedelta(days=4) # To take care of weekends & holidays.
        type_after_end = client.get_ticker_details(ticker=row['ticker'], date = day_after_end).type
    except Exception as e:
        type_after_end = 'CS'

    # Apparently an ordinary share is the same as a common stock... Also do not forget ADRCs!
    if type_before_start not in ['CS', 'ADRC', 'OS', None] or type_after_end not in ['CS', 'ADRC', 'OS', None]:
        IDs_to_remove.append(row['ID'])
        print(row['ID'])

# Write to file. We need this later to make updating easier. Else we would have to do 25k-50k requests every time we update.
import csv
with open(POLYGON_DATA_PATH + f'raw/IDs_to_remove.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerow(IDs_to_remove)

# %% [markdown]
# The amount of incorrect classified common stock is unacceptable:

# %%
### (OPTIONAL)
incorrect_classified = tickers_v1[tickers_v1['ID'].isin(IDs_to_remove)]
print(len(incorrect_classified))
incorrect_classified.to_csv("../data/incorrect_classified.csv")
incorrect_classified.tail(3)[['ticker', 'name', 'active', 'start_date', 'end_date']]
# Out:
# 391
#       ticker                                               name  active  \
# 14454  WTMAR  Welsbach Technology Metals Acquisition Corp. o...   False
# 14532   XFLT                      XAI Octagon Floating Rate Alt   False
# 14671  YSACW  Yellowstone Acquisition Company Warrants to pu...   False
#
#        start_date    end_date
# 14454  2022-01-21  2022-08-29
# 14532  2019-04-02  2019-08-09
# 14671  2020-12-08  2021-02-09

# %%
###
with open(POLYGON_DATA_PATH + f'raw/IDs_to_remove.csv', 'r') as file:
    reader = csv.reader(file)
    IDs_to_remove = next(reader)

print(len(tickers_v1))
tickers_v1 = tickers_v1[~tickers_v1['ID'].isin(IDs_to_remove)]
tickers_v1.reset_index(inplace=True, drop=True)
print(len(tickers_v1))
# Out:
# 8775
# 8384

# %% [markdown]
# Finally, we save the merged and cleaned ticker list to <code>tickers_v2.csv</code>.

# %%
###
print(f"Total tickers: {len(tickers_v1)}")
print(f"Unique tickers: {len(tickers_v1['ticker'].unique())}")

tickers_v1 = tickers_v1.reset_index(drop=True)
tickers_v1 = tickers_v1[["ID", "ticker", "name", "active", "start_date", "end_date", "type", "cik", "composite_figi"]]
tickers_v1.to_csv("../data/tickers_v2.csv")
# Out:
# Total tickers: 8384
# Unique tickers: 8236

# %% [markdown]
# # 3.7 Updates
# 1. Run the first cell below to create a backup of <code>tickers_v3</code>. Later when we download data, we will compare the old to the new ticker list to determine which stocks and dates to update, instead of downloading everything.
# 1. Update END_DATE.
# 2. Run the 3 ### cells in 3.1. This updates the folder of ticker lists. It takes around 7 seconds per day.
# 3. Run the cell below to update <code>tickers_v1</code>. Instead of merging all ticker lists, only the new ones are merged.
# 4. Run the cells with ### in 3.5 and 3.6 to update <code>tickers_v2</code>. We skip checking if a stock is a common stock is not because it is very time consuming. If you do not want to skip it, run the two '### (OPTIONAL)' rows.
#
# Because this is tedious, I will create a script to do updates for everything when I have finished the series.

# %%
tickers_v3 = get_tickers(3)
tickers_v3.to_csv("../data/tickers_v3_old.csv")

# %%
from utils import get_tickers

tickers_v1 = get_tickers(1, cik_as_float=False)
current_end_date = tickers_v1['end_date'].max()

market_days = get_market_dates()
first_trading_date_after_current_end_date = first_trading_date_after_equal(current_end_date + timedelta(days=1))
last_trading_date_before_end_date = last_trading_date_before_equal(END_DATE)

for day in market_days:
    if day == current_end_date:
        our_tickers = tickers_v1
        our_tickers.loc[our_tickers['active'], 'end_date'] = np.NaN

    elif day >= first_trading_date_after_current_end_date and day <= END_DATE:
        # Get new ticker list to update ours
        tickers_day_i = pd.read_csv(
            POLYGON_DATA_PATH + f"raw/tickers/{day.isoformat()}.csv",
            index_col=0,
            keep_default_na=False,
            na_values=['#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NULL', 'NaN', 'None', 'n/a', 'nan', 'null']
        )
        tickers_day_i = tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]]
        tickers_day_i = tickers_day_i[tickers_day_i["active"] == True]
        tickers_day_i.reset_index(inplace=True, drop=True)

        # Preliminary check: no duplicates
        if our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
            raise Exception("There are duplicates!")

        if tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]].duplicated().all():
            raise Exception("There are duplicates!")

        # DELISTINGS
        indicator_delisted = our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], how='left', indicator=True)

        indicator_delisted['_merge'] = np.where(our_tickers["active"], indicator_delisted['_merge'], "both") # ERROR FIX: If in our ticker list we have already set it inactive, it should not be added to the list of delisted stocks again. By setting _merge to "both" we skip the already inactive stocks.

        indicator_delisted = indicator_delisted["_merge"] # Only get the indicator
        delisted_tickers = our_tickers[indicator_delisted == "left_only"]

        # NEW LISTINGS
        indicator_new = tickers_day_i[["ticker", "name", "active", "cik", "composite_figi", "type"]].merge(our_tickers[["ticker", "name", "active", "cik", "composite_figi", "type"]], on=["ticker", "name", "active", "cik", "composite_figi", "type"], 
                        how='left', indicator=True)
        indicator_new = indicator_new["_merge"]
        new_tickers = tickers_day_i[indicator_new == "left_only"]

        # PROCESS DELISTINGS
        previous_day = market_days[market_days.index(day) - 1] # Getting previous trading day
        our_tickers.loc[indicator_delisted == "left_only", "end_date"] = previous_day
        our_tickers.loc[indicator_delisted == "left_only", "active"] = False
        
        # PROCESS NEW LISTINGS
        our_tickers = pd.concat([our_tickers, new_tickers])

        our_tickers.reset_index(inplace=True, drop=True)
        our_tickers['start_date'].fillna(value=day, inplace=True)
        
        # Final checks
        if our_tickers[["ticker", "name", "active", "type", "start_date"]].isnull().values.any():
            #null_data = our_tickers[our_tickers[["ticker", "name", "active", "type", "start_date"]].isnull().any(axis=1)]
            raise Exception("There are missing values.")
        
        print(f'{day.isoformat()}: Amount of stocks {len(our_tickers)}')
        
        # Finalize
        if day == last_trading_date_before_end_date:
            our_tickers["end_date"].fillna(value=last_trading_date_before_end_date, inplace=True)
            our_tickers = our_tickers.sort_values(by=["ticker", "end_date"]).reset_index(drop=True)
            our_tickers[["ticker", "name", "active", "start_date", "end_date", "type", "cik", "composite_figi"]].to_csv("../data/tickers_v1.csv")
# Out:
# 2023-09-05: Amount of stocks 14794
# 2023-09-06: Amount of stocks 14799
# 2023-09-07: Amount of stocks 14802
