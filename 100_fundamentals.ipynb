# %%
import financedatabase as fd
import pandas as pd

# %%
# Initialize the Equities database
equities = fd.Equities()

# Obtain all data available excluding international exchanges
equities.select().to_csv('../data/FINANCE_DB.csv')

# %%
file = pd.read_parquet(f"../data/SF1.parquet")

# %%
file[file['ticker'] == 'AAC']
# Out:
#         ticker dimension calendardate     datekey reportperiod lastupdated  \
# 98044      AAC       ART   2021-03-31  2021-05-17   2021-03-31  2023-08-08
# 98063      AAC       MRQ   2020-09-30  2020-09-30   2020-09-30  2023-08-08
# 98071      AAC       MRQ   2023-03-31  2023-03-31   2023-03-31  2023-08-08
# 98072      AAC       MRT   2020-12-31  2020-12-31   2020-12-31  2023-08-08
# 98081      AAC       MRT   2022-06-30  2022-06-30   2022-06-30  2023-08-08
# ...        ...       ...          ...         ...          ...         ...
# 1809963    AAC       MRY   2020-12-31  2020-12-31   2020-12-31  2023-08-08
# 1809964    AAC       MRY   2021-12-31  2021-12-31   2021-12-31  2023-08-08
# 1809965    AAC       MRY   2022-12-31  2022-12-31   2022-12-31  2023-08-08
# 2238228    AAC       MRT   2020-03-31  2020-03-31   2020-03-31  2023-08-08
# 2390103    AAC       MRT   2020-09-30  2020-09-30   2020-09-30  2023-08-08
#
# ...
