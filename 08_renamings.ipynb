# %% [markdown]
# # 8.1 Merging ticker changes
# This is optional. If you want it ticker-centric or don't want to get a stockanalysis.com subscription, you can just skip this part.
#
# To get a list of ticker changes, We can loop through all tickers and query <code>Ticker Events</code> but this only works with non-delisted companies. And although you can infer it based on the ticker list by looking at whether the cik or figi has changed, that is very messy. Because a company can stay the same even if the ticker and cik/figi change. I actually did it, and it did found that it did not match the Polygon <code>Ticker Events</code>. Then I stumbled on [stockanalysis.com](https://stockanalysis.com/actions/changes/) where you can find all ticker changes for only 10 bucks a month. The first month is even free. You have to manually download them for each year and put them in the <code>stockanalysis/raw/ticker_changes/</code> folder.
#
# After merging those we will save the result to <code>raw/renamings.csv</code> which will contain the columns <code>['from', 'to', 'now', 'date']</code>.

# %%
from tickers import get_tickers, get_ticker_changes
from times import get_market_dates, get_market_calendar
from datetime import datetime, date, time
import pandas as pd
import os
DATA_PATH = "../data/polygon/"
END_DATE = date(2024, 3, 1)

# %%
###
# Aggregate the csv's
all_ticker_changes = []
for file in os.listdir(DATA_PATH + "../stockanalysis/raw/ticker_changes/"):
    ticker_changes_year = pd.read_csv(DATA_PATH + "../stockanalysis/raw/ticker_changes/" + file, parse_dates=True, index_col=0, usecols=["Date", "Old", "New"])
    all_ticker_changes.append(ticker_changes_year)

ticker_changes = pd.concat(all_ticker_changes)
ticker_changes = pd.concat(all_ticker_changes)
ticker_changes.rename(columns={"Old": "from", 
                               "New": "to"}, inplace=True)
ticker_changes.index.names = ['date']
ticker_changes.sort_index(inplace=True)
ticker_changes.to_csv(DATA_PATH + "../stockanalysis/ticker_changes.csv")

# %%
print(len(ticker_changes))
ticker_changes[ticker_changes['from'] == "FB"]
# Out:
# 4347
#            from    to
# date
# 2022-06-09   FB  META

# %% [markdown]
# There are a whopping 4347 ticker changes from 2003 to now that we have to take care of. But at least this was very easy to get.
#
# Now we will use them to merge our data. We have to be aware that it is possible for a ticker to used multiple times, so the <code>ticker_changes.csv</code> may contain multiple of the same tickers in the 'from' and 'to' column.
#
# After processing the ticker changes we will create a <code>tickers_v5.csv</code> which will be our definitive ticker list. This contains a column 'tickers_old', which will containa list of (date_of_change, ticker) pairs. So if A changes to B on day 2, and B changes to C on day 5, tickers_old for D will contain [[2, A], [5, B]].
#
# The process will be as follows:
# * As long as we have ticker changes to process
#     * Loop through <code>tickers_v4.csv</code>.
#         * Get the next trading date after 'end_date_data'.
#         * Search in <code>tickers_changes.csv</code> if there is a ticker change on this date.
#         * If it does:
#             * The stock data will be merged.
#             * In <code>tickers_v4.csv</code> we will change "ticker" to the new ticker and add a list [date, ticker] to "tickers_old".
#             * All other rows will be merged such as "start_date". For identifiers such as FIGI we will take the last available value. For the ID we will keep the original. If we do not do this, we might run into problems with identical IDs.
#             * The row of the old ticker will be deleted
#             * **We need to restart the loop!** If we don't the following can happen: Let's assume that a ticker was renamed from A -> B -> C -> D but that the order in which it appears in our ticker list is C, D, A, B. Using our loop, C gets merged with D. Then the loop checks D, which has no renamings. Then A gets merged with B. Then B gets merged with C, however that is incorrect! B should be merged with the new D, which contains C. Any double+ renamings have the risk of being in the 'wrong order'.
#             * Of course we must not forget that there can be adjustments on day 1 of the ticker change. There should be laws to prohibit this.
#
# Note: if a ticker A goes OTC and then comes back and changes to B, then we will have two files: one of the A before OTC and the A+B after OTC named B.

# %%
tickers_v4 = get_tickers(v=4)
market_dates = get_market_dates()
ticker_changes = get_ticker_changes()

tickers_v4.insert(loc = 2, column = 'tickers_old', value = [[] for _ in range(len(tickers_v4))])

while True:
    # tickers_v4 gets smaller by 1 element every time we run this loop.
    for index_from, row_from in tickers_v4.copy().iterrows():
        # Get values
        type_from = row_from['type']
        if type_from == "INDEX":
            continue
        id_from = row_from['ID']
        ticker_from = row_from['ticker']
        start_date_from = row_from['start_date']
        end_date_from = row_from['end_date']
        start_data_from = row_from['start_data']
        end_data_from = row_from['end_data']
        if end_data_from == END_DATE:
            continue

        start_data_to = market_dates[market_dates.index(end_data_from) + 1]

        # Get ticker changes 
        change = ticker_changes[(ticker_changes.index == start_data_to) & (ticker_changes['from'] == ticker_from)]
        if change.empty:
            continue
        elif len(change) > 1:
            raise Exception("Duplicate!")
        ticker_to = change['to'].values[0]

        # Set values of new ticker
        row_to = tickers_v4[(tickers_v4['start_data'] == start_data_to) & (tickers_v4['ticker'] == ticker_to)]
        if row_to.empty:
            continue
        index_to = row_to.index[0]
        id_to = row_to['ID'].values[0]
        tickers_v4.loc[index_to, "tickers_old"].append([start_data_to.isoformat(), ticker_from])
        tickers_v4.loc[index_to, "start_date"] = start_date_from
        tickers_v4.loc[index_to, "start_data"] = start_data_from

        # Do the actual merging
        from_ = pd.read_parquet(DATA_PATH + f"processed/m1/{id_from}.parquet")
        to = pd.read_parquet(DATA_PATH + f"processed/m1/{id_to}.parquet")

        # Because companies like to be annoying, a split/dividend can take place at the same time as a ticker change. We have to account for this. An example is TYDE -> OCTO with a 50:1 reverse split. However this is much easier than 5_process_raw_data.ipynb, because there is at most a single split. This is rare, but there are still a handful of cases.
        if os.path.isfile(DATA_PATH + f"raw/adjustments/{ticker_to}.csv"):
            adjustments = pd.read_csv(DATA_PATH + f"raw/adjustments/{ticker_to}.csv", parse_dates=True, index_col=0)
            adjustments.index = pd.to_datetime(adjustments.index).date
            adjustments = adjustments[(adjustments.index == start_data_to)]

            # SPLIT ADJUSTMENT
            split = adjustments[adjustments.type == 'SPLIT']
            if len(split) > 0:
                split_amount = split['amount'][0]

                from_[['open', 'high', 'low', 'close']] = from_[['open', 'high', 'low', 'close']].multiply(split_amount)
                from_['volume'] = from_['volume'].divide(split_amount)

            # DIVIDEND ADJUSTMENT - REUN is the only case, not clear what happened there.
            dividend = adjustments[adjustments.type == 'DIV']
            if len(dividend) > 0:
                print(ticker_to)
                market_hours = get_market_calendar()
                market_hours = market_hours[['regular_close']]

                cum_div_date = end_data_from
                cum_div_time = market_hours.loc[cum_div_date][0]
                cum_div_datetime = datetime.combine(cum_div_date, cum_div_time)
                cum_div_datetime = (from_[from_.index <= cum_div_datetime].index).max()
                cum_div_close = from_.loc[cum_div_datetime, 'close']
                dividend_amount = dividend['amount'][0]
                    
                adjustment_factor = 1 - dividend_amount/cum_div_close

                from_[['open', 'high', 'low', 'close']] = from_[['open', 'high', 'low', 'close']].multiply(adjustment_factor)
                from_['volume'] = from_['volume'].divide(adjustment_factor)
                from_ = round(from_, 4)
                from_['volume'] = from_['volume'].astype(int)
            
            # ROUNDING
            if len(split) > 0 or len(dividend) > 0:
                from_ = round(from_, 4)
                from_['volume'] = from_['volume'].astype(int)

        # If on the old ticker, there are divs/splits on start_data_to (start of new ticker), then something is wrong.
        if os.path.isfile(DATA_PATH + f"raw/adjustments/{ticker_from}.csv"):
            adjustments = pd.read_csv(DATA_PATH + f"raw/adjustments/{ticker_from}.csv", parse_dates=True, index_col=0)
            adjustments.index = pd.to_datetime(adjustments.index).date
            adjustments = adjustments[(adjustments.index == start_data_to)]
            assert len(adjustments) == 0

        pd.concat([from_, to]).to_parquet(DATA_PATH + f"processed/m1/{id_to}.parquet", engine="fastparquet", row_group_offsets=25000)
        # pd.concat([from_, to]).to_parquet(DATA_PATH + f"processed/m1/{new_id}.parquet", engine="pyarrow", compression = 'brotli', row_group_size = 25000)

        # Delete old ticker from ticker list. You can also remove the files, but that is not necessary. In backtesting you will always loop over the ticker list and not over de files in the folder.
        #os.remove(path = DATA_PATH + f"processed/m1/{id_from}.parquet") # Removal of old renamed ticker (not necessary)
        tickers_v4.drop(index_from, inplace=True)
        tickers_v4.reset_index(inplace=True, drop=True)
        print(f"Ticker change {ticker_from} -> {ticker_to} on {start_data_to} has been processed")
        print(f"{index_from/len(tickers_v4)*100:.1f}% | Length of tickers_v4 is {len(tickers_v4)}")
        break
    
    # If we have reached the end of the loop, it means we have processed everything. Then we can stop.
    if index_from >= (len(tickers_v4)-1):
        break

tickers_v4.to_csv("../data/tickers_v5.csv")
# Out:
# Ticker change AACQ -> ORGN on 2021-06-25 has been processed
# 0.1% | Length of tickers_v4 is 8568
# Ticker change AAXN -> AXON on 2021-01-26 has been processed
# 0.3% | Length of tickers_v4 is 8567
# Ticker change ACAC -> MYPS on 2021-06-22 has been processed
# 0.7% | Length of tickers_v4 is 8566
# Ticker change ACAM -> LOTZ on 2021-01-22 has been processed
# 0.7% | Length of tickers_v4 is 8565
# Ticker change ACEV -> TMPO on 2022-11-23 has been processed
# 0.9% | Length of tickers_v4 is 8564
# Ticker change ACIC -> ACHR on 2021-09-17 has been processed
# 1.0% | Length of tickers_v4 is 8563
# Ticker change ACND -> MKTW on 2021-07-22 has been processed
# 1.1% | Length of tickers_v4 is 8562
# Ticker change ACTC -> PTRA on 2021-06-15 has been processed
# 1.2% | Length of tickers_v4 is 8561
# Ticker change ACTD -> OPAL on 2022-07-22 has been processed
# 1.2% | Length of tickers_v4 is 8560
# Ticker change ACTT -> FREE on 2020-06-25 has been processed
# 1.2% | Length of tickers_v4 is 8559
# Ticker change ADF -> HGTY on 2021-12-03 has been processed
# 1.4% | Length of tickers_v4 is 8558
# Ticker change ADGI -> IVVD on 2022-09-13 has been processed
# 1.4% | Length of tickers_v4 is 8557
# Ticker change ADMP -> DMK on 2023-09-08 has been processed
# 1.5% | Length of tickers_v4 is 8556
# Ticker change ADRO -> KDNY on 2020-10-06 has been processed
# 1.6% | Length of tickers_v4 is 8555
# Ticker change ADS -> BFH on 2022-04-04 has been processed
# 1.6% | Length of tickers_v4 is 8554
# Ticker change AEHA -> OCEA on 2023-02-15 has been processed
# 1.8% | Length of tickers_v4 is 8553
# Ticker change AERC -> MKUL on 2023-01-12 has been processed
# 2.0% | Length of tickers_v4 is 8552
# Ticker change AESE -> AGAE on 2022-12-01 has been processed
# 2.0% | Length of tickers_v4 is 8551
# Ticker change AETI -> SLNG on 2019-07-29 has been processed
# 2.0% | Length of tickers_v4 is 8550
# Ticker change AFIN -> RTL on 2022-02-15 has been processed
# 2.2% | Length of tickers_v4 is 8549
# Ticker change AGC -> GRAB on 2021-12-02 has been processed
# 2.3% | Length of tickers_v4 is 8548
# Ticker change AHAC -> HUMA on 2021-08-27 has been processed
# 2.6% | Length of tickers_v4 is 8547
# Ticker change AHC -> DALN on 2021-06-29 has been processed
# 2.6% | Length of tickers_v4 is 8546
# Ticker change AI -> AAIC on 2020-10-26 has been processed
# 2.7% | Length of tickers_v4 is 8545
# Ticker change AIKI -> DOMH on 2022-12-22 has been processed
# 2.8% | Length of tickers_v4 is 8544
# Ticker change AINV -> MFIC on 2022-08-15 has been processed
# 2.9% | Length of tickers_v4 is 8543
# Ticker change AITB -> XAIR on 2019-07-15 has been processed
# 3.0% | Length of tickers_v4 is 8542
# Ticker change AJAX -> CZOO on 2021-08-27 has been processed
# 3.0% | Length of tickers_v4 is 8541
# Ticker change AKER -> MYMD on 2021-04-19 has been processed
# 3.1% | Length of tickers_v4 is 8540
# Ticker change AKG -> GAU on 2020-05-05 has been processed
# 3.1% | Length of tickers_v4 is 8539
# Ticker change ALPA -> CTCX on 2023-07-17 has been processed
# 3.8% | Length of tickers_v4 is 8538
# Ticker change ALTM -> KNTK on 2022-02-23 has been processed
# 4.0% | Length of tickers_v4 is 8537
# Ticker change ALUS -> FREY on 2021-07-08 has been processed
# 4.0% | Length of tickers_v4 is 8536
# Ticker change AMCI -> ADN on 2021-02-05 has been processed
# 4.3% | Length of tickers_v4 is 8535
# Ticker change AMHC -> JSPR on 2021-09-27 has been processed
# 4.4% | Length of tickers_v4 is 8534
# Ticker change AMOT -> ALNT on 2023-08-23 has been processed
# 4.5% | Length of tickers_v4 is 8533
# Ticker change AMRH -> ENVB on 2020-12-31 has been processed
# 4.7% | Length of tickers_v4 is 8532
# Ticker change AMV -> NXU on 2023-05-15 has been processed
# 4.9% | Length of tickers_v4 is 8531
# Ticker change ANCN -> CMMB on 2021-03-17 has been processed
# 5.0% | Length of tickers_v4 is 8530
# Ticker change ANDA -> SNAX on 2021-07-21 has been processed
# 5.0% | Length of tickers_v4 is 8529
# Ticker change ANPC -> FRES on 2023-05-22 has been processed
# 5.2% | Length of tickers_v4 is 8528
# Ticker change ANTM -> ELV on 2022-06-28 has been processed
# 5.2% | Length of tickers_v4 is 8527
# Ticker change AOBC -> SWBI on 2020-06-01 has been processed
# 5.3% | Length of tickers_v4 is 8526
# Ticker change AONE -> MKFG on 2021-07-15 has been processed
# 5.3% | Length of tickers_v4 is 8525
# Ticker change APOP -> QNRX on 2021-10-29 has been processed
# 5.7% | Length of tickers_v4 is 8524
# Ticker change APSG -> GBTG on 2022-05-31 has been processed
# 5.8% | Length of tickers_v4 is 8523
# Ticker change APXT -> AVPT on 2021-07-02 has been processed
# 5.9% | Length of tickers_v4 is 8522
# Ticker change APY -> CHX on 2020-06-04 has been processed
# 5.9% | Length of tickers_v4 is 8521
# Ticker change AQXP -> NLTX on 2019-08-12 has been processed
# 6.0% | Length of tickers_v4 is 8520
# Ticker change ARCI -> JAN on 2019-09-11 has been processed
# 6.2% | Length of tickers_v4 is 8519
# Ticker change ARPO -> AADI on 2021-08-27 has been processed
# 6.6% | Length of tickers_v4 is 8518
# Ticker change ARTA -> PRE on 2022-05-18 has been processed
# 6.7% | Length of tickers_v4 is 8517
# Ticker change ARYA -> IMTX on 2020-07-02 has been processed
# 6.8% | Length of tickers_v4 is 8516
# Ticker change ARYA -> NAUT on 2021-06-10 has been processed
# 6.8% | Length of tickers_v4 is 8515
# Ticker change ASPC -> STIX on 2022-08-04 has been processed
# 7.1% | Length of tickers_v4 is 8514
# Ticker change ASPL -> UP on 2021-07-14 has been processed
# 7.1% | Length of tickers_v4 is 8513
# Ticker change ATAC -> OWL on 2021-05-20 has been processed
# 7.4% | Length of tickers_v4 is 8512
# Ticker change ATHN -> HLGN on 2021-12-31 has been processed
# 7.6% | Length of tickers_v4 is 8511
# Ticker change ATMR -> FATH on 2021-12-27 has been processed
# 7.7% | Length of tickers_v4 is 8510
# Ticker change AURC -> BETR on 2023-08-24 has been processed
# 8.2% | Length of tickers_v4 is 8509
# Ticker change AVAC -> BENF on 2023-06-08 has been processed
# 8.3% | Length of tickers_v4 is 8508
# Ticker change AVCO -> ALBT on 2022-11-10 has been processed
# 8.4% | Length of tickers_v4 is 8507
# Ticker change AXGT -> SIOX on 2020-11-13 has been processed
# 8.9% | Length of tickers_v4 is 8506
# Ticker change AZRX -> FWBI on 2021-09-22 has been processed
# 9.2% | Length of tickers_v4 is 8505
# Ticker change AZYO -> ELUT on 2023-09-07 has been processed
# 9.2% | Length of tickers_v4 is 8504
# Ticker change BAMR -> BNRE on 2022-12-14 has been processed
# 9.4% | Length of tickers_v4 is 8503
# Ticker change BASI -> NOTV on 2021-03-22 has been processed
# 9.6% | Length of tickers_v4 is 8502
# Ticker change BBI -> FRTX on 2022-09-08 has been processed
# 9.7% | Length of tickers_v4 is 8501
# BVH
# Ticker change BBX -> BVH on 2020-10-01 has been processed
# 9.9% | Length of tickers_v4 is 8500
# Ticker change BCAC -> APGN on 2022-08-01 has been processed
# 9.9% | Length of tickers_v4 is 8499
# Ticker change BCEI -> CIVI on 2021-11-02 has been processed
# 10.0% | Length of tickers_v4 is 8498
# Ticker change BCOR -> AVTA on 2023-01-26 has been processed
# 10.1% | Length of tickers_v4 is 8497
# Ticker change BCTG -> TNGX on 2021-08-11 has been processed
# 10.2% | Length of tickers_v4 is 8496
# Ticker change BCYP -> SABS on 2021-10-25 has been processed
# 10.2% | Length of tickers_v4 is 8495
# Ticker change BFT -> PSFE on 2021-03-31 has been processed
# 10.7% | Length of tickers_v4 is 8494
# Ticker change BGCP -> BGC on 2023-07-03 has been processed
# 10.8% | Length of tickers_v4 is 8493
# Ticker change BHSE -> COEP on 2022-10-31 has been processed
# 11.1% | Length of tickers_v4 is 8492
# Ticker change BHTG -> RENO on 2021-12-13 has been processed
# 11.1% | Length of tickers_v4 is 8491
# Ticker change BIOS -> OPCH on 2020-02-03 has been processed
# 11.3% | Length of tickers_v4 is 8490
# Ticker change BLI -> CELL on 2023-03-22 has been processed
# 11.8% | Length of tickers_v4 is 8489
# Ticker change BLL -> BALL on 2022-05-10 has been processed
# 11.9% | Length of tickers_v4 is 8488
# Ticker change BMRG -> EOSE on 2020-11-17 has been processed
# 12.2% | Length of tickers_v4 is 8487
# Ticker change BOAS -> SLNA on 2022-10-27 has been processed
# 12.5% | Length of tickers_v4 is 8486
# Ticker change BOMN -> BOC on 2022-02-22 has been processed
# 12.6% | Length of tickers_v4 is 8485
# Ticker change BOWX -> WE on 2021-10-21 has been processed
# 12.7% | Length of tickers_v4 is 8484
# Ticker change BPR -> BPYU on 2020-03-02 has been processed
# 12.8% | Length of tickers_v4 is 8483
# Ticker change BRKS -> AZTA on 2021-12-01 has been processed
# 13.2% | Length of tickers_v4 is 8482
# Ticker change BRPA -> NRXP on 2021-05-25 has been processed
# 13.3% | Length of tickers_v4 is 8481
# Ticker change BRPM -> ALTG on 2020-02-18 has been processed
# 13.3% | Length of tickers_v4 is 8480
# Ticker change BRPM -> FAZE on 2022-07-20 has been processed
# 13.3% | Length of tickers_v4 is 8479
# Ticker change BSGA -> BTDR on 2023-04-14 has been processed
# 13.5% | Length of tickers_v4 is 8478
# Ticker change BSN -> EVTL on 2021-12-16 has been processed
# 13.6% | Length of tickers_v4 is 8477
# Ticker change BTB -> BETS on 2023-09-08 has been processed
# 13.7% | Length of tickers_v4 is 8476
# Ticker change BTN -> FGH on 2022-12-27 has been processed
# 13.9% | Length of tickers_v4 is 8475
# Ticker change BTNB -> PGRU on 2022-03-18 has been processed
# 13.9% | Length of tickers_v4 is 8474
# Ticker change BTX -> LCTX on 2019-08-12 has been processed
# 14.0% | Length of tickers_v4 is 8473
# Ticker change BTX -> ERNA on 2022-10-17 has been processed
# 14.0% | Length of tickers_v4 is 8472
# Ticker change BURG -> SONN on 2020-04-02 has been processed
# 14.1% | Length of tickers_v4 is 8471
# Ticker change BVXV -> SCNI on 2023-09-07 has been processed
# 14.2% | Length of tickers_v4 is 8470
# Ticker change BWMC -> ATCX on 2020-02-18 has been processed
# 14.3% | Length of tickers_v4 is 8469
# Ticker change CAHC -> LMDX on 2021-09-29 has been processed
# 14.8% | Length of tickers_v4 is 8468
# Ticker change CAP -> DOMA on 2021-07-29 has been processed
# 15.0% | Length of tickers_v4 is 8467
# Ticker change CAPA -> QSI on 2021-06-11 has been processed
# 15.0% | Length of tickers_v4 is 8466
# Ticker change CATB -> ATXS on 2021-09-09 has been processed
# 15.3% | Length of tickers_v4 is 8465
# Ticker change CATS -> OTRK on 2020-07-07 has been processed
# 15.3% | Length of tickers_v4 is 8464
# Ticker change CBAH -> AMPS on 2021-12-10 has been processed
# 15.3% | Length of tickers_v4 is 8463
# Ticker change CBTX -> STEL on 2022-10-03 has been processed
# 15.6% | Length of tickers_v4 is 8462
# Ticker change CCC -> CLVT on 2021-02-01 has been processed
# 15.8% | Length of tickers_v4 is 8461
# Ticker change CCCL -> AEHL on 2020-10-15 has been processed
# 15.8% | Length of tickers_v4 is 8460
# Ticker change CCH -> UTZ on 2020-08-31 has been processed
# 15.8% | Length of tickers_v4 is 8459
# Ticker change CCIV -> LCID on 2021-07-26 has been processed
# 15.8% | Length of tickers_v4 is 8458
# Ticker change CCNC -> GDC on 2023-01-10 has been processed
# 15.9% | Length of tickers_v4 is 8457
# Ticker change CCX -> SKIL on 2021-06-14 has been processed
# 16.1% | Length of tickers_v4 is 8456
# Ticker change CCXX -> MPLN on 2020-10-09 has been processed
# 16.1% | Length of tickers_v4 is 8455
# Ticker change CDEV -> PR on 2022-09-02 has been processed
# 16.2% | Length of tickers_v4 is 8454
# Ticker change CECE -> CECO on 2022-11-07 has been processed
# 16.4% | Length of tickers_v4 is 8453
# Ticker change CECO -> PRDO on 2020-01-02 has been processed
# 16.4% | Length of tickers_v4 is 8452
# Ticker change CENH -> ARQQ on 2021-09-07 has been processed
# 16.6% | Length of tickers_v4 is 8451
# Ticker change CENQ -> VGAS on 2023-02-16 has been processed
# 16.6% | Length of tickers_v4 is 8450
# Ticker change CERC -> AVTX on 2021-08-26 has been processed
# 16.7% | Length of tickers_v4 is 8449
# Ticker change CFAC -> LIDR on 2021-08-18 has been processed
# 16.8% | Length of tickers_v4 is 8448
# Ticker change CFFA -> GCMG on 2020-11-18 has been processed
# 16.9% | Length of tickers_v4 is 8447
# Ticker change CFII -> VIEW on 2021-03-09 has been processed
# 16.9% | Length of tickers_v4 is 8446
# Ticker change CFV -> SATL on 2022-01-26 has been processed
# 17.0% | Length of tickers_v4 is 8445
# Ticker change CFVI -> RUM on 2022-09-19 has been processed
# 17.0% | Length of tickers_v4 is 8444
# Ticker change CFX -> ENOV on 2022-04-05 has been processed
# 17.0% | Length of tickers_v4 is 8443
# Ticker change CGIX -> VYNT on 2021-03-31 has been processed
# 17.1% | Length of tickers_v4 is 8442
# Ticker change CGRO -> INVZ on 2021-04-06 has been processed
# 17.1% | Length of tickers_v4 is 8441
# Ticker change CHAC -> PHGE on 2019-10-29 has been processed
# 17.2% | Length of tickers_v4 is 8440
# Ticker change CHAQ -> RCOR on 2021-09-03 has been processed
# 17.2% | Length of tickers_v4 is 8439
# Ticker change CHFS -> NUWE on 2021-04-27 has been processed
# 17.3% | Length of tickers_v4 is 8438
# Ticker change CHFW -> SRZN on 2021-08-12 has been processed
# 17.3% | Length of tickers_v4 is 8437
# Ticker change CHG -> LUXH on 2022-11-07 has been processed
# 17.3% | Length of tickers_v4 is 8436
# Ticker change CHKE -> APEX on 2019-06-27 has been processed
# 17.3% | Length of tickers_v4 is 8435
# Ticker change CHWA -> PET on 2022-08-10 has been processed
# 17.6% | Length of tickers_v4 is 8434
# Ticker change CIDM -> CNVS on 2023-05-23 has been processed
# 17.7% | Length of tickers_v4 is 8433
# Ticker change CIIC -> ARVL on 2021-03-25 has been processed
# 17.8% | Length of tickers_v4 is 8432
# Ticker change CIIG -> ZAPP on 2023-05-01 has been processed
# 17.8% | Length of tickers_v4 is 8431
# Ticker change CINR -> SIRE on 2022-03-01 has been processed
# 17.9% | Length of tickers_v4 is 8430
# Ticker change CLAQ -> KITT on 2022-09-13 has been processed
# 18.1% | Length of tickers_v4 is 8429
# Ticker change CLBR -> PSQH on 2023-07-20 has been processed
# 18.2% | Length of tickers_v4 is 8428
# Ticker change CLBS -> LSTA on 2022-09-15 has been processed
# 18.2% | Length of tickers_v4 is 8427
# Ticker change CLI -> VRE on 2021-12-10 has been processed
# 18.4% | Length of tickers_v4 is 8426
# Ticker change CLII -> EVGO on 2021-07-02 has been processed
# 18.4% | Length of tickers_v4 is 8425
# Ticker change CLNC -> BRSP on 2021-06-25 has been processed
# 18.5% | Length of tickers_v4 is 8424
# Ticker change CLSN -> IMNN on 2022-09-21 has been processed
# 18.7% | Length of tickers_v4 is 8423
# Ticker change CLXT -> CBUS on 2023-06-01 has been processed
# 18.8% | Length of tickers_v4 is 8422
# Ticker change CMFN -> ICMB on 2019-09-03 has been processed
# 18.9% | Length of tickers_v4 is 8421
# Ticker change CMII -> SLGC on 2021-09-02 has been processed
# 18.9% | Length of tickers_v4 is 8420
# Ticker change CMLF -> SMFR on 2021-07-23 has been processed
# 18.9% | Length of tickers_v4 is 8419
# Ticker change CMLT -> EQRX on 2021-12-20 has been processed
# 19.0% | Length of tickers_v4 is 8418
# Ticker change CNAT -> HSTO on 2020-05-27 has been processed
# 19.2% | Length of tickers_v4 is 8417
# Ticker change CNTQ -> DFLI on 2022-10-10 has been processed
# 19.6% | Length of tickers_v4 is 8416
# Ticker change COG -> CTRA on 2021-10-04 has been processed
# 19.8% | Length of tickers_v4 is 8415
# Ticker change COVA -> ECX on 2022-12-21 has been processed
# 20.3% | Length of tickers_v4 is 8414
# Ticker change CPAA -> ADV on 2020-10-29 has been processed
# 20.3% | Length of tickers_v4 is 8413
# Ticker change CPST -> CGRN on 2021-04-22 has been processed
# 20.6% | Length of tickers_v4 is 8412
# Ticker change CPTA -> LRFC on 2021-07-02 has been processed
# 20.7% | Length of tickers_v4 is 8411
# Ticker change CPUH -> ALUR on 2023-08-02 has been processed
# 20.7% | Length of tickers_v4 is 8410
# Ticker change CREE -> WOLF on 2021-10-04 has been processed
# 20.9% | Length of tickers_v4 is 8409
# Ticker change CRSA -> LVOX on 2021-06-22 has been processed
# 21.2% | Length of tickers_v4 is 8408
# Ticker change CRTX -> QNCX on 2022-08-01 has been processed
# 21.3% | Length of tickers_v4 is 8407
# Ticker change CRY -> AORT on 2022-01-24 has been processed
# 21.4% | Length of tickers_v4 is 8406
# Ticker change CSCW -> ADD on 2022-11-01 has been processed
# 21.5% | Length of tickers_v4 is 8405
# Ticker change CSU -> SNDA on 2021-11-15 has been processed
# 21.7% | Length of tickers_v4 is 8404
# Ticker change CTAC -> GDYN on 2020-03-06 has been processed
# 21.7% | Length of tickers_v4 is 8403
# Ticker change CTAC -> KORE on 2021-10-01 has been processed
# 21.7% | Length of tickers_v4 is 8402
# Ticker change CTIB -> YHGJ on 2023-09-25 has been processed
# 21.9% | Length of tickers_v4 is 8401
# Ticker change CTRA -> AMR on 2021-02-04 has been processed
# 22.0% | Length of tickers_v4 is 8400
# Ticker change CTRP -> TCOM on 2019-11-05 has been processed
# 22.1% | Length of tickers_v4 is 8399
# Ticker change CTRV -> HEPA on 2019-07-23 has been processed
# 22.1% | Length of tickers_v4 is 8398
# Ticker change CVLB -> LFMD on 2021-02-22 has been processed
# 22.5% | Length of tickers_v4 is 8397
# Ticker change CVTI -> CVLG on 2020-07-06 has been processed
# 22.7% | Length of tickers_v4 is 8396
# Ticker change CYTX -> PSTV on 2019-07-29 has been processed
# 23.2% | Length of tickers_v4 is 8395
# Ticker change DBCP -> PTRS on 2020-08-19 has been processed
# 23.6% | Length of tickers_v4 is 8394
# Ticker change DBDR -> CMPO on 2021-12-28 has been processed
# 23.6% | Length of tickers_v4 is 8393
# Ticker change DCAR -> AYRO on 2020-05-29 has been processed
# 23.7% | Length of tickers_v4 is 8392
# Ticker change DCIX -> PSHG on 2020-03-30 has been processed
# 23.8% | Length of tickers_v4 is 8391
# Ticker change DCRB -> HYZN on 2021-07-19 has been processed
# 23.8% | Length of tickers_v4 is 8390
# Ticker change DCRC -> SLDP on 2021-12-09 has been processed
# 23.8% | Length of tickers_v4 is 8389
# Ticker change DCRD -> HHRS on 2023-02-27 has been processed
# 23.8% | Length of tickers_v4 is 8388
# Ticker change DCRN -> DCFC on 2022-01-14 has been processed
# 23.8% | Length of tickers_v4 is 8387
# Ticker change DDMX -> CDRO on 2021-12-01 has been processed
# 23.9% | Length of tickers_v4 is 8386
# Ticker change DEAC -> DKNG on 2020-04-24 has been processed
# 24.0% | Length of tickers_v4 is 8385
# Ticker change DEH -> RBOT on 2021-09-20 has been processed
# 24.0% | Length of tickers_v4 is 8384
# Ticker change DFBH -> AHCO on 2019-11-11 has been processed
# 24.1% | Length of tickers_v4 is 8383
# Ticker change DFFN -> CRVO on 2023-08-17 has been processed
# 24.1% | Length of tickers_v4 is 8382
# Ticker change DFHT -> CMAX on 2021-06-09 has been processed
# 24.1% | Length of tickers_v4 is 8381
# Ticker change DFNS -> IRNT on 2021-08-27 has been processed
# 24.2% | Length of tickers_v4 is 8380
# Ticker change DFPH -> TOI on 2021-11-15 has been processed
# 24.2% | Length of tickers_v4 is 8379
# Ticker change DGNR -> CCCS on 2021-08-02 has been processed
# 24.3% | Length of tickers_v4 is 8378
# Ticker change DGNS -> CVT on 2021-12-09 has been processed
# 24.3% | Length of tickers_v4 is 8377
# Ticker change DGSE -> ELA on 2019-12-18 has been processed
# 24.3% | Length of tickers_v4 is 8376
# Ticker change DHHC -> UHG on 2023-03-31 has been processed
# 24.4% | Length of tickers_v4 is 8375
# Ticker change DISCA -> WBD on 2022-04-11 has been processed
# 24.6% | Length of tickers_v4 is 8374
# Ticker change DMPI -> KTRA on 2020-08-20 has been processed
# 24.9% | Length of tickers_v4 is 8373
# Ticker change DMYD -> GENI on 2021-04-21 has been processed
# 24.9% | Length of tickers_v4 is 8372
# Ticker change DMYI -> IONQ on 2021-10-01 has been processed
# 24.9% | Length of tickers_v4 is 8371
# Ticker change DMYQ -> PL on 2021-12-08 has been processed
# 24.9% | Length of tickers_v4 is 8370
# Ticker change DMYT -> RSI on 2020-12-30 has been processed
# 25.0% | Length of tickers_v4 is 8369
# Ticker change DNAA -> AKLI on 2022-08-22 has been processed
# 25.0% | Length of tickers_v4 is 8368
# Ticker change DNAC -> PROK on 2022-07-12 has been processed
# 25.0% | Length of tickers_v4 is 8367
# Ticker change DNAY -> TBIO on 2023-01-04 has been processed
# 25.0% | Length of tickers_v4 is 8366
# Ticker change DNJR -> BTBT on 2020-08-07 has been processed
# 25.0% | Length of tickers_v4 is 8365
# Ticker change DPHC -> RIDE on 2020-10-26 has been processed
# 25.4% | Length of tickers_v4 is 8364
# Ticker change DPW -> NILE on 2021-12-13 has been processed
# 25.5% | Length of tickers_v4 is 8363
# Ticker change DRAD -> STRR on 2021-01-04 has been processed
# 25.5% | Length of tickers_v4 is 8362
# Ticker change DSAC -> NOTE on 2022-08-01 has been processed
# 25.7% | Length of tickers_v4 is 8361
# Ticker change DTOC -> AONC on 2023-09-21 has been processed
# 25.9% | Length of tickers_v4 is 8360
# Ticker change DWIN -> FOXO on 2022-09-16 has been processed
# 26.1% | Length of tickers_v4 is 8359
# Ticker change DYNS -> SNTI on 2022-06-09 has been processed
# 26.3% | Length of tickers_v4 is 8358
# Ticker change EARS -> CYTO on 2021-07-26 has been processed
# 26.4% | Length of tickers_v4 is 8357
# Ticker change EBAC -> OCS on 2023-03-03 has been processed
# 26.4% | Length of tickers_v4 is 8356
# Ticker change ECA -> OVV on 2020-01-27 has been processed
# 26.6% | Length of tickers_v4 is 8355
# Ticker change EDNT -> BBIG on 2020-11-12 has been processed
# 26.8% | Length of tickers_v4 is 8354
# Ticker change EDTX -> METX on 2020-03-31 has been processed
# 26.9% | Length of tickers_v4 is 8353
# Ticker change EJFA -> PGY on 2022-06-23 has been processed
# 27.4% | Length of tickers_v4 is 8352
# Ticker change ELY -> MODG on 2022-09-07 has been processed
# 27.8% | Length of tickers_v4 is 8351
# Ticker change EMPW -> HLLY on 2021-07-19 has been processed
# 28.0% | Length of tickers_v4 is 8350
# Ticker change ENFA -> BZFD on 2021-12-06 has been processed
# 28.1% | Length of tickers_v4 is 8349
# Ticker change ENOB -> RENB on 2023-08-07 has been processed
# 28.2% | Length of tickers_v4 is 8348
# Ticker change ENPC -> GRNT on 2022-10-25 has been processed
# 28.2% | Length of tickers_v4 is 8347
# Ticker change ENVI -> GRNA on 2022-02-03 has been processed
# 28.4% | Length of tickers_v4 is 8346
# Ticker change ERA -> VTOL on 2020-06-12 has been processed
# 28.8% | Length of tickers_v4 is 8345
# Ticker change ERES -> ABL on 2023-07-05 has been processed
# 28.9% | Length of tickers_v4 is 8344
# Ticker change ERYP -> PHXM on 2023-06-29 has been processed
# 29.0% | Length of tickers_v4 is 8343
# Ticker change ESSC -> NWTN on 2022-11-14 has been processed
# 29.3% | Length of tickers_v4 is 8342
# Ticker change ETM -> AUD on 2021-04-09 has been processed
# 29.4% | Length of tickers_v4 is 8341
# Ticker change EUSG -> ADSE on 2021-12-23 has been processed
# 29.6% | Length of tickers_v4 is 8340
# Ticker change EVLV -> IMBI on 2019-07-17 has been processed
# 29.8% | Length of tickers_v4 is 8339
# Ticker change EVSI -> BEEM on 2020-09-15 has been processed
# 30.0% | Length of tickers_v4 is 8338
# Ticker change EXPC -> BLDE on 2021-05-10 has been processed
# 30.2% | Length of tickers_v4 is 8337
# Ticker change EYEG -> KPRX on 2021-11-08 has been processed
# 30.3% | Length of tickers_v4 is 8336
# Ticker change EYES -> VANI on 2022-08-31 has been processed
# 30.3% | Length of tickers_v4 is 8335
# Ticker change FACT -> CSLR on 2023-07-18 has been processed
# 30.4% | Length of tickers_v4 is 8334
# Ticker change FAII -> ATIP on 2021-06-17 has been processed
# 30.4% | Length of tickers_v4 is 8333
# Ticker change FB -> META on 2022-06-09 has been processed
# 30.6% | Length of tickers_v4 is 8332
# Ticker change FBHS -> FBIN on 2022-12-15 has been processed
# 30.6% | Length of tickers_v4 is 8331
# Ticker change FCAC -> SHCR on 2021-07-02 has been processed
# 30.7% | Length of tickers_v4 is 8330
# Ticker change FCAU -> STLA on 2021-01-19 has been processed
# 30.8% | Length of tickers_v4 is 8329
# Ticker change FDEF -> PFC on 2020-06-22 has been processed
# 31.0% | Length of tickers_v4 is 8328
# Ticker change FEYE -> MNDT on 2021-10-05 has been processed
# 31.2% | Length of tickers_v4 is 8327
# Ticker change FGNA -> OPFI on 2021-07-21 has been processed
# 31.5% | Length of tickers_v4 is 8326
# Ticker change FII -> FHI on 2020-02-03 has been processed
# 31.7% | Length of tickers_v4 is 8325
# Ticker change FISV -> FI on 2023-06-07 has been processed
# 31.8% | Length of tickers_v4 is 8324
# Ticker change FLAC -> NAMS on 2022-11-23 has been processed
# 31.9% | Length of tickers_v4 is 8323
# Ticker change FLAG -> CLDI on 2023-09-13 has been processed
# 31.9% | Length of tickers_v4 is 8322
# Ticker change FLDM -> LAB on 2022-04-06 has been processed
# 31.9% | Length of tickers_v4 is 8321
# Ticker change FLKS -> SLRX on 2019-07-22 has been processed
# 32.0% | Length of tickers_v4 is 8320
# Ticker change FLMN -> STR on 2022-06-06 has been processed
# 32.0% | Length of tickers_v4 is 8319
# Ticker change FMCI -> TTCF on 2020-10-16 has been processed
# 32.3% | Length of tickers_v4 is 8318
# Ticker change FORE -> PIII on 2021-12-06 has been processed
# 32.7% | Length of tickers_v4 is 8317
# Ticker change FOUN -> RBT on 2022-08-16 has been processed
# 32.8% | Length of tickers_v4 is 8316
# Ticker change FPAC -> GB on 2020-08-31 has been processed
# 32.9% | Length of tickers_v4 is 8315
# Ticker change FRAC -> NEX on 2019-10-31 has been processed
# 32.9% | Length of tickers_v4 is 8314
# Ticker change FRX -> BODY on 2021-06-28 has been processed
# 33.4% | Length of tickers_v4 is 8313
# Ticker change FSDC -> GMTX on 2021-02-08 has been processed
# 33.5% | Length of tickers_v4 is 8312
# Ticker change FSII -> PRDS on 2021-12-27 has been processed
# 33.5% | Length of tickers_v4 is 8311
# Ticker change FSRV -> KPLT on 2021-06-10 has been processed
# 33.6% | Length of tickers_v4 is 8310
# Ticker change FTAC -> PAYA on 2020-10-19 has been processed
# 33.7% | Length of tickers_v4 is 8309
# Ticker change FTIV -> PWP on 2021-06-25 has been processed
# 33.9% | Length of tickers_v4 is 8308
# Ticker change FTOC -> PAYO on 2021-06-28 has been processed
# 33.9% | Length of tickers_v4 is 8307
# REUN
# Ticker change FTRP -> REUN on 2022-08-17 has been processed
# 34.0% | Length of tickers_v4 is 8306
# Ticker change FUSE -> ML on 2021-09-23 has been processed
# 34.2% | Length of tickers_v4 is 8305
# Ticker change FVAC -> MP on 2020-11-18 has been processed
# 34.2% | Length of tickers_v4 is 8304
# Ticker change FWAA -> SMRT on 2021-08-25 has been processed
# 34.3% | Length of tickers_v4 is 8303
# Ticker change GBOX -> RVYL on 2022-10-24 has been processed
# 34.8% | Length of tickers_v4 is 8302
# Ticker change GBRG -> SDA on 2023-05-18 has been processed
# 34.8% | Length of tickers_v4 is 8301
# Ticker change GBS -> INBS on 2022-10-27 has been processed
# 34.8% | Length of tickers_v4 is 8300
# Ticker change GCAC -> CPTN on 2022-02-11 has been processed
# 34.8% | Length of tickers_v4 is 8299
# Ticker change GEC -> GEG on 2020-12-29 has been processed
# 35.2% | Length of tickers_v4 is 8298
# Ticker change GEMP -> NRBO on 2019-12-31 has been processed
# 35.3% | Length of tickers_v4 is 8297
# Ticker change GGPI -> PSNY on 2022-06-24 has been processed
# 35.7% | Length of tickers_v4 is 8296
# Ticker change GHIV -> UWMC on 2021-01-22 has been processed
# 35.7% | Length of tickers_v4 is 8295
# Ticker change GHVI -> MTTR on 2021-07-23 has been processed
# 35.8% | Length of tickers_v4 is 8294
# Ticker change GIG -> KLR on 2019-11-26 has been processed
# 35.9% | Length of tickers_v4 is 8293
# Ticker change GIG -> BBAI on 2021-12-08 has been processed
# 35.9% | Length of tickers_v4 is 8292
# Ticker change GIK -> ZEV on 2021-05-07 has been processed
# 35.9% | Length of tickers_v4 is 8291
# Ticker change GIX -> UPH on 2021-06-10 has been processed
# 36.0% | Length of tickers_v4 is 8290
# Ticker change GLAC -> GTEC on 2019-10-29 has been processed
# 36.0% | Length of tickers_v4 is 8289
# Ticker change GLAQ -> AFRI on 2022-06-10 has been processed
# 36.1% | Length of tickers_v4 is 8288
# Ticker change GLBL -> ALTI on 2023-01-04 has been processed
# 36.1% | Length of tickers_v4 is 8287
# Ticker change GLEE -> GSD on 2022-10-17 has been processed
# 36.1% | Length of tickers_v4 is 8286
# Ticker change GLEO -> SHPW on 2021-09-30 has been processed
# 36.1% | Length of tickers_v4 is 8285
# Ticker change GLOW -> OBLG on 2020-03-09 has been processed
# 36.3% | Length of tickers_v4 is 8284
# Ticker change GLTA -> MRT on 2023-07-11 has been processed
# 36.4% | Length of tickers_v4 is 8283
# Ticker change GMBT -> SWVL on 2022-04-01 has been processed
# 36.5% | Length of tickers_v4 is 8282
# Ticker change GMHI -> LAZR on 2020-12-03 has been processed
# 36.5% | Length of tickers_v4 is 8281
# Ticker change GMII -> SOND on 2022-01-19 has been processed
# 36.5% | Length of tickers_v4 is 8280
# Ticker change GMTX -> IRON on 2022-12-30 has been processed
# 36.6% | Length of tickers_v4 is 8279
# Ticker change GNPK -> RDW on 2021-09-03 has been processed
# 36.8% | Length of tickers_v4 is 8278
# Ticker change GOED -> POL on 2022-07-22 has been processed
# 37.0% | Length of tickers_v4 is 8277
# Ticker change GOGN -> LZM on 2023-07-06 has been processed
# 37.0% | Length of tickers_v4 is 8276
# Ticker change GPAQ -> HOFV on 2020-07-02 has been processed
# 37.2% | Length of tickers_v4 is 8275
# Ticker change GPCO -> HOLO on 2022-09-19 has been processed
# 37.2% | Length of tickers_v4 is 8274
# Ticker change GRAF -> VLDR on 2020-09-30 has been processed
# 37.4% | Length of tickers_v4 is 8273
# Ticker change GRAM -> AENZ on 2020-11-12 has been processed
# 37.4% | Length of tickers_v4 is 8272
# Ticker change GRAY -> CALC on 2023-03-21 has been processed
# 37.4% | Length of tickers_v4 is 8271
# Ticker change GRIL -> SDOT on 2023-07-27 has been processed
# 37.5% | Length of tickers_v4 is 8270
# Ticker change GRNV -> HLBZ on 2021-08-16 has been processed
# 37.6% | Length of tickers_v4 is 8269
# Ticker change GRSH -> PAE on 2020-02-11 has been processed
# 37.7% | Length of tickers_v4 is 8268
# Ticker change GRSV -> AMBP on 2021-08-05 has been processed
# 37.7% | Length of tickers_v4 is 8267
# Ticker change GRVI -> UPXI on 2022-08-19 has been processed
# 37.7% | Length of tickers_v4 is 8266
# Ticker change GSAH -> VRT on 2020-02-10 has been processed
# 37.8% | Length of tickers_v4 is 8265
# Ticker change GSAH -> MIR on 2021-10-21 has been processed
# 37.8% | Length of tickers_v4 is 8264
# Ticker change GSRM -> BTM on 2023-07-03 has been processed
# 38.0% | Length of tickers_v4 is 8263
# Ticker change GSVC -> SSSS on 2019-08-01 has been processed
# 38.1% | Length of tickers_v4 is 8262
# Ticker change GSX -> GOTU on 2021-05-06 has been processed
# 38.1% | Length of tickers_v4 is 8261
# Ticker change GTXI -> ONCT on 2019-06-10 has been processed
# 38.3% | Length of tickers_v4 is 8260
# Ticker change GWAC -> CIFR on 2021-08-30 has been processed
# 38.5% | Length of tickers_v4 is 8259
# Ticker change GXGX -> CELU on 2021-07-19 has been processed
# 38.6% | Length of tickers_v4 is 8258
# Ticker change HAIR -> VERO on 2019-11-08 has been processed
# 38.8% | Length of tickers_v4 is 8257
# Ticker change HAPP -> PAVS on 2023-03-14 has been processed
# 38.8% | Length of tickers_v4 is 8256
# Ticker change HCAC -> GOEV on 2020-12-22 has been processed
# 39.0% | Length of tickers_v4 is 8255
# Ticker change HCCC -> DRTS on 2022-03-08 has been processed
# 39.1% | Length of tickers_v4 is 8254
# Ticker change HCCO -> TLMD on 2020-11-02 has been processed
# 39.1% | Length of tickers_v4 is 8253
# Ticker change HCHC -> VATE on 2021-09-20 has been processed
# 39.2% | Length of tickers_v4 is 8252
# Ticker change HCP -> PEAK on 2019-11-05 has been processed
# 39.2% | Length of tickers_v4 is 8251
# Ticker change HEB -> AIM on 2019-09-03 has been processed
# 39.4% | Length of tickers_v4 is 8250
# Ticker change HEBT -> NISN on 2020-11-16 has been processed
# 39.4% | Length of tickers_v4 is 8249
# Ticker change HEC -> TALK on 2021-06-23 has been processed
# 39.4% | Length of tickers_v4 is 8248
# Ticker change HFC -> DINO on 2022-03-15 has been processed
# 39.6% | Length of tickers_v4 is 8247
# Ticker change HFEN -> AEI on 2021-02-05 has been processed
# 39.6% | Length of tickers_v4 is 8246
# Ticker change HGSH -> GGE on 2022-03-23 has been processed
# 39.7% | Length of tickers_v4 is 8245
# Ticker change HHC -> HHH on 2023-08-14 has been processed
# 39.7% | Length of tickers_v4 is 8244
# Ticker change HHHH -> SJ on 2020-05-11 has been processed
# 39.7% | Length of tickers_v4 is 8243
# Ticker change HIIQ -> BFYT on 2020-03-06 has been processed
# 39.9% | Length of tickers_v4 is 8242
# Ticker change HILS -> THAR on 2023-09-25 has been processed
# 39.9% | Length of tickers_v4 is 8241
# Ticker change HJLI -> NVNO on 2021-10-01 has been processed
# 40.0% | Length of tickers_v4 is 8240
# Ticker change HKIB -> AMTD on 2022-01-31 has been processed
# 40.1% | Length of tickers_v4 is 8239
# Ticker change HLBZ -> MCOM on 2023-03-31 has been processed
# 40.1% | Length of tickers_v4 is 8238
# Ticker change HLXA -> MLTX on 2022-04-06 has been processed
# 40.3% | Length of tickers_v4 is 8237
# Ticker change HMI -> ZEPP on 2021-02-25 has been processed
# 40.4% | Length of tickers_v4 is 8236
# Ticker change HOL -> ASTR on 2021-07-01 has been processed
# 40.6% | Length of tickers_v4 is 8235
# Ticker change HPX -> AMBI on 2023-03-06 has been processed
# 41.0% | Length of tickers_v4 is 8234
# Ticker change HRS -> LHX on 2019-07-01 has been processed
# 41.1% | Length of tickers_v4 is 8233
# Ticker change HSAC -> IMVT on 2019-12-19 has been processed
# 41.1% | Length of tickers_v4 is 8232
# Ticker change HSAQ -> OBIO on 2023-01-27 has been processed
# 41.2% | Length of tickers_v4 is 8231
# Ticker change HSC -> NVRI on 2023-06-20 has been processed
# 41.2% | Length of tickers_v4 is 8230
# Ticker change HSGX -> OCGN on 2019-09-30 has been processed
# 41.2% | Length of tickers_v4 is 8229
# Ticker change HTBX -> NHWK on 2022-05-03 has been processed
# 41.4% | Length of tickers_v4 is 8228
# Ticker change HUSN -> FRGT on 2022-05-27 has been processed
# 41.7% | Length of tickers_v4 is 8227
# Ticker change CIFS -> FRGT on 2020-05-08 has been processed
# 18.2% | Length of tickers_v4 is 8226
# Ticker change HVBT -> HIVE on 2021-09-14 has been processed
# 41.8% | Length of tickers_v4 is 8225
# Ticker change HX -> AHG on 2021-12-16 has been processed
# 41.9% | Length of tickers_v4 is 8224
# Ticker change HYAC -> ARKO on 2020-12-23 has been processed
# 41.9% | Length of tickers_v4 is 8223
# Ticker change HYAC -> BTMD on 2022-05-27 has been processed
# 41.9% | Length of tickers_v4 is 8222
# Ticker change HZAC -> SEAT on 2021-10-19 has been processed
# 42.1% | Length of tickers_v4 is 8221
# Ticker change IACA -> TBLA on 2021-06-30 has been processed
# 42.1% | Length of tickers_v4 is 8220
# Ticker change IACB -> CTV on 2021-12-01 has been processed
# 42.1% | Length of tickers_v4 is 8219
# Ticker change IDRA -> ACGN on 2023-01-18 has been processed
# 42.8% | Length of tickers_v4 is 8218
# Ticker change IGAP -> GCTK on 2022-03-14 has been processed
# 43.0% | Length of tickers_v4 is 8217
# Ticker change IGNY -> PKBO on 2022-11-02 has been processed
# 43.1% | Length of tickers_v4 is 8216
# Ticker change IIAC -> ZGN on 2021-12-20 has been processed
# 43.2% | Length of tickers_v4 is 8215
# Ticker change IIVI -> COHR on 2022-09-08 has been processed
# 43.3% | Length of tickers_v4 is 8214
# Ticker change IKNX -> WULF on 2021-12-14 has been processed
# 43.3% | Length of tickers_v4 is 8213
# Ticker change IMAC -> BACK on 2022-08-08 has been processed
# 43.4% | Length of tickers_v4 is 8212
# Ticker change IMPX -> LVWR on 2022-09-27 has been processed
# 43.7% | Length of tickers_v4 is 8211
# Ticker change IMRA -> ELVN on 2023-02-24 has been processed
# 43.7% | Length of tickers_v4 is 8210
# Ticker change INAQ -> MILE on 2021-02-10 has been processed
# 43.8% | Length of tickers_v4 is 8209
# Ticker change INNT -> NMTR on 2020-05-04 has been processed
# 44.2% | Length of tickers_v4 is 8208
# Ticker change INS -> CCRD on 2021-12-29 has been processed
# 44.2% | Length of tickers_v4 is 8207
# Ticker change INSU -> SFT on 2020-10-15 has been processed
# 44.3% | Length of tickers_v4 is 8206
# Ticker change INT -> WKC on 2023-06-16 has been processed
# 44.3% | Length of tickers_v4 is 8205
# Ticker change INTL -> SNEX on 2020-07-06 has been processed
# 44.4% | Length of tickers_v4 is 8204
# Ticker change IPAX -> LUNR on 2023-02-14 has been processed
# 44.8% | Length of tickers_v4 is 8203
# Ticker change IPOA -> SPCE on 2019-10-28 has been processed
# 44.9% | Length of tickers_v4 is 8202
# Ticker change IPOB -> OPEN on 2020-12-21 has been processed
# 44.9% | Length of tickers_v4 is 8201
# Ticker change IPOC -> CLOV on 2021-01-08 has been processed
# 44.9% | Length of tickers_v4 is 8200
# Ticker change IPOE -> SOFI on 2021-06-01 has been processed
# 44.9% | Length of tickers_v4 is 8199
# Ticker change IPV -> AEVA on 2021-03-15 has been processed
# 44.9% | Length of tickers_v4 is 8198
# Ticker change IPVA -> GETR on 2022-12-09 has been processed
# 44.9% | Length of tickers_v4 is 8197
# Ticker change IRET -> CSR on 2020-12-21 has been processed
# 45.1% | Length of tickers_v4 is 8196
# Ticker change ISIG -> LDWY on 2023-08-04 has been processed
# 45.3% | Length of tickers_v4 is 8195
# Ticker change ISNS -> AATC on 2021-07-21 has been processed
# 45.4% | Length of tickers_v4 is 8194
# Ticker change ISOS -> BOWL on 2021-12-16 has been processed
# 45.4% | Length of tickers_v4 is 8193
# Ticker change ISR -> CATX on 2023-02-21 has been processed
# 45.4% | Length of tickers_v4 is 8192
# Ticker change ITAC -> ARBE on 2021-10-08 has been processed
# 45.5% | Length of tickers_v4 is 8191
# Ticker change ITCB -> ITCL on 2023-05-01 has been processed
# 45.5% | Length of tickers_v4 is 8190
# Ticker change ITHX -> MOND on 2022-07-19 has been processed
# 45.6% | Length of tickers_v4 is 8189
# Ticker change IVAN -> SES on 2022-02-04 has been processed
# 45.8% | Length of tickers_v4 is 8188
# Ticker change JATT -> ZURA on 2023-03-21 has been processed
# 46.1% | Length of tickers_v4 is 8187
# Ticker change JCIC -> BAER on 2023-01-25 has been processed
# 46.2% | Length of tickers_v4 is 8186
# Ticker change JCOM -> ZD on 2021-10-08 has been processed
# 46.2% | Length of tickers_v4 is 8185
# Ticker change JCS -> PEGY on 2022-03-29 has been processed
# 46.2% | Length of tickers_v4 is 8184
# Ticker change JFK -> EQOS on 2020-10-01 has been processed
# 46.4% | Length of tickers_v4 is 8183
# Ticker change JIH -> JBI on 2021-06-08 has been processed
# 46.5% | Length of tickers_v4 is 8182
# Ticker change JMAC -> APLM on 2023-03-30 has been processed
# 46.6% | Length of tickers_v4 is 8181
# Ticker change JMU -> MFH on 2020-02-12 has been processed
# 46.7% | Length of tickers_v4 is 8180
# Ticker change JUPW -> SHOT on 2023-09-15 has been processed
# 47.0% | Length of tickers_v4 is 8179
# Ticker change JW.A -> WLY on 2022-04-01 has been processed
# 47.0% | Length of tickers_v4 is 8178
# Ticker change JW.B -> WLYB on 2022-04-01 has been processed
# 47.0% | Length of tickers_v4 is 8177
# Ticker change JWAC -> CJET on 2023-06-02 has been processed
# 47.0% | Length of tickers_v4 is 8176
# Ticker change JWS -> CANO on 2021-06-04 has been processed
# 47.0% | Length of tickers_v4 is 8175
# Ticker change KBLM -> ATNF on 2020-11-09 has been processed
# 47.4% | Length of tickers_v4 is 8174
# Ticker change KCAC -> QS on 2020-11-27 has been processed
# 47.4% | Length of tickers_v4 is 8173
# Ticker change KCAC -> WBX on 2021-10-04 has been processed
# 47.4% | Length of tickers_v4 is 8172
# Ticker change KINZ -> CXAI on 2023-03-15 has been processed
# 47.8% | Length of tickers_v4 is 8171
# Ticker change KMPH -> ZVRA on 2023-03-01 has been processed
# 48.0% | Length of tickers_v4 is 8170
# Ticker change KOOL -> THMO on 2019-11-01 has been processed
# 48.3% | Length of tickers_v4 is 8169
# Ticker change KSMT -> GDEV on 2021-08-27 has been processed
# 48.7% | Length of tickers_v4 is 8168
# Ticker change KTOV -> PPBT on 2020-12-22 has been processed
# 48.8% | Length of tickers_v4 is 8167
# Ticker change KURI -> BBLN on 2021-10-22 has been processed
# 48.9% | Length of tickers_v4 is 8166
# Ticker change KVSB -> KIND on 2021-11-08 has been processed
# 48.9% | Length of tickers_v4 is 8165
# Ticker change LAAA -> OSA on 2022-12-07 has been processed
# 49.1% | Length of tickers_v4 is 8164
# Ticker change LATN -> PROC on 2021-09-30 has been processed
# 49.3% | Length of tickers_v4 is 8163
# Ticker change LB -> BBWI on 2021-08-03 has been processed
# 49.4% | Length of tickers_v4 is 8162
# Ticker change LCA -> GNOG on 2020-12-30 has been processed
# 49.6% | Length of tickers_v4 is 8161
# Ticker change LCY -> HLMN on 2021-07-15 has been processed
# 49.7% | Length of tickers_v4 is 8160
# Ticker change LEGO -> ASTL on 2021-10-20 has been processed
# 49.9% | Length of tickers_v4 is 8159
# Ticker change LFAC -> LSEA on 2021-01-08 has been processed
# 50.1% | Length of tickers_v4 is 8158
# Ticker change LGC -> ID on 2020-11-23 has been processed
# 50.2% | Length of tickers_v4 is 8157
# Ticker change LGVW -> BFLY on 2021-02-16 has been processed
# 50.4% | Length of tickers_v4 is 8156
# Ticker change LHC -> DMS on 2020-07-16 has been processed
# 50.5% | Length of tickers_v4 is 8155
# Ticker change LIII -> LOCL on 2021-11-22 has been processed
# 50.6% | Length of tickers_v4 is 8154
# Ticker change LION -> SMX on 2023-03-08 has been processed
# 50.7% | Length of tickers_v4 is 8153
# Ticker change LIVK -> AGIL on 2021-08-24 has been processed
# 50.8% | Length of tickers_v4 is 8152
# Ticker change LIVX -> LVO on 2021-10-06 has been processed
# 50.9% | Length of tickers_v4 is 8151
# Ticker change LJAQ -> MLEC on 2023-01-03 has been processed
# 50.9% | Length of tickers_v4 is 8150
# Ticker change LLIT -> NEGG on 2021-05-20 has been processed
# 51.0% | Length of tickers_v4 is 8149
# Ticker change LLL -> JXJT on 2022-10-10 has been processed
# 51.0% | Length of tickers_v4 is 8148
# Ticker change KBSF -> JXJT on 2021-10-13 has been processed
# 47.6% | Length of tickers_v4 is 8147
# Ticker change LLNW -> EGIO on 2022-06-16 has been processed
# 51.0% | Length of tickers_v4 is 8146
# Ticker change LMAO -> ICU on 2022-10-31 has been processed
# 51.1% | Length of tickers_v4 is 8145
# Ticker change LNDC -> LFCR on 2022-11-15 has been processed
# 51.3% | Length of tickers_v4 is 8144
# Ticker change LNFA -> ZFOX on 2022-08-04 has been processed
# 51.3% | Length of tickers_v4 is 8143
# Ticker change LOAC -> LBPS on 2021-03-22 has been processed
# 51.4% | Length of tickers_v4 is 8142
# Ticker change LOAK -> DNMR on 2020-12-30 has been processed
# 51.4% | Length of tickers_v4 is 8141
# Ticker change LOKB -> NVTS on 2021-10-20 has been processed
# 51.5% | Length of tickers_v4 is 8140
# Ticker change LPI -> VTLE on 2023-01-09 has been processed
# 51.7% | Length of tickers_v4 is 8139
# Ticker change LRAD -> GNSS on 2019-10-23 has been processed
# 51.8% | Length of tickers_v4 is 8138
# Ticker change LSAC -> VINC on 2020-12-24 has been processed
# 51.9% | Length of tickers_v4 is 8137
# Ticker change LSAQ -> SNCE on 2021-10-07 has been processed
# 51.9% | Length of tickers_v4 is 8136
# Ticker change LSPR -> ZVSA on 2022-12-13 has been processed
# 52.0% | Length of tickers_v4 is 8135
# Ticker change LWAC -> EFTR on 2021-08-26 has been processed
# 52.6% | Length of tickers_v4 is 8134
# Ticker change LYL -> MATH on 2022-12-13 has been processed
# 52.7% | Length of tickers_v4 is 8133
# Ticker change MAAC -> ROIV on 2021-10-01 has been processed
# 52.9% | Length of tickers_v4 is 8132
# Ticker change MAAQ -> CDIO on 2022-10-26 has been processed
# 52.9% | Length of tickers_v4 is 8131
# Ticker change MACQ -> ADTH on 2021-12-23 has been processed
# 53.0% | Length of tickers_v4 is 8130
# Ticker change MAGS -> SNT on 2021-09-30 has been processed
# 53.0% | Length of tickers_v4 is 8129
# Ticker change MCAC -> PLBY on 2021-02-11 has been processed
# 53.6% | Length of tickers_v4 is 8128
# Ticker change MCAD -> BTTX on 2021-10-29 has been processed
# 53.6% | Length of tickers_v4 is 8127
# Ticker change MCAE -> ETAO on 2023-02-21 has been processed
# 53.6% | Length of tickers_v4 is 8126
# Ticker change MCG -> SHCO on 2023-03-20 has been processed
# 53.7% | Length of tickers_v4 is 8125
# Ticker change MCMJ -> LFLY on 2022-02-07 has been processed
# 53.8% | Length of tickers_v4 is 8124
# Ticker change MDCA -> STGW on 2021-08-03 has been processed
# 54.0% | Length of tickers_v4 is 8123
# Ticker change METX -> BTCT on 2023-09-29 has been processed
# 54.6% | Length of tickers_v4 is 8122
# Ticker change MGEN -> VRDN on 2021-01-20 has been processed
# 54.8% | Length of tickers_v4 is 8121
# Ticker change MGTA -> DNTH on 2023-09-12 has been processed
# 55.0% | Length of tickers_v4 is 8120
# Ticker change MICT -> TIO on 2023-02-27 has been processed
# 55.1% | Length of tickers_v4 is 8119
# Ticker change MITC -> STKH on 2022-08-03 has been processed
# 55.3% | Length of tickers_v4 is 8118
# Ticker change MKGI -> NXTP on 2021-07-09 has been processed
# 55.5% | Length of tickers_v4 is 8117
# Ticker change MKTY -> SLNH on 2021-11-04 has been processed
# 55.5% | Length of tickers_v4 is 8116
# Ticker change MLHR -> MLKN on 2021-11-01 has been processed
# 55.6% | Length of tickers_v4 is 8115
# Ticker change MLND -> TPST on 2021-06-28 has been processed
# 55.7% | Length of tickers_v4 is 8114
# Ticker change MMMB -> MAMA on 2023-08-02 has been processed
# 55.9% | Length of tickers_v4 is 8113
# Ticker change MNCL -> ASLE on 2020-12-23 has been processed
# 56.0% | Length of tickers_v4 is 8112
# Ticker change MNLO -> VYNE on 2020-09-08 has been processed
# 56.1% | Length of tickers_v4 is 8111
# Ticker change MOSC -> VVNT on 2020-01-21 has been processed
# 56.6% | Length of tickers_v4 is 8110
# Ticker change MOSY -> PRSO on 2021-12-20 has been processed
# 56.6% | Length of tickers_v4 is 8109
# Ticker change MOTN -> DCGO on 2021-11-08 has been processed
# 56.6% | Length of tickers_v4 is 8108
# Ticker change MOTV -> FRGE on 2022-03-22 has been processed
# 56.6% | Length of tickers_v4 is 8107
# Ticker change MPAC -> MMV on 2023-01-05 has been processed
# 56.7% | Length of tickers_v4 is 8106
# Ticker change MSG -> MSGS on 2020-04-20 has been processed
# 57.4% | Length of tickers_v4 is 8105
# Ticker change MSPR -> LIFW on 2023-01-03 has been processed
# 57.5% | Length of tickers_v4 is 8104
# Ticker change LCAP -> LIFW on 2022-05-24 has been processed
# 49.9% | Length of tickers_v4 is 8103
# Ticker change MTAC -> TLSI on 2023-08-11 has been processed
# 57.6% | Length of tickers_v4 is 8102
# Ticker change MTBC -> CCLD on 2023-01-10 has been processed
# 57.6% | Length of tickers_v4 is 8101
# Ticker change MTMT -> MPU on 2023-02-06 has been processed
# 57.8% | Length of tickers_v4 is 8100
# Ticker change ACY -> MPU on 2022-03-28 has been processed
# 1.3% | Length of tickers_v4 is 8099
# Ticker change MTP -> BDRX on 2023-03-27 has been processed
# 57.8% | Length of tickers_v4 is 8098
# Ticker change MTSL -> SBET on 2021-07-28 has been processed
# 57.9% | Length of tickers_v4 is 8097
# Ticker change MUDS -> HYMC on 2020-06-01 has been processed
# 58.0% | Length of tickers_v4 is 8096
# Ticker change MURF -> CDT on 2023-09-25 has been processed
# 58.1% | Length of tickers_v4 is 8095
# Ticker change MWK -> ATER on 2021-04-30 has been processed
# 58.2% | Length of tickers_v4 is 8094
# Ticker change MYL -> VTRS on 2020-11-17 has been processed
# 58.3% | Length of tickers_v4 is 8093
# Ticker change MYOS -> MDVL on 2020-11-18 has been processed
# 58.4% | Length of tickers_v4 is 8092
# Ticker change NAKD -> CENN on 2022-01-14 has been processed
# 58.5% | Length of tickers_v4 is 8091
# Ticker change NANO -> ONTO on 2019-10-28 has been processed
# 58.6% | Length of tickers_v4 is 8090
# Ticker change NBA -> MIMO on 2021-08-16 has been processed
# 58.8% | Length of tickers_v4 is 8089
# Ticker change NBAC -> NVVE on 2021-03-23 has been processed
# 58.8% | Length of tickers_v4 is 8088
# Ticker change NCBS -> NIC on 2022-05-24 has been processed
# 59.0% | Length of tickers_v4 is 8087
# Ticker change NEBC -> ROVR on 2021-08-02 has been processed
# 59.2% | Length of tickers_v4 is 8086
# Ticker change NEBU -> LPRO on 2020-06-11 has been processed
# 59.2% | Length of tickers_v4 is 8085
# Ticker change NETE -> MULN on 2021-11-05 has been processed
# 59.5% | Length of tickers_v4 is 8084
# Ticker change NFC -> NFH on 2019-12-19 has been processed
# 59.7% | Length of tickers_v4 is 8083
# Ticker change NGA -> LEV on 2021-05-07 has been processed
# 59.8% | Length of tickers_v4 is 8082
# Ticker change NGAB -> EMBK on 2021-11-11 has been processed
# 59.8% | Length of tickers_v4 is 8081
# Ticker change NGAC -> XOS on 2021-08-20 has been processed
# 59.9% | Length of tickers_v4 is 8080
# Ticker change NGCA -> VORB on 2021-12-30 has been processed
# 59.9% | Length of tickers_v4 is 8079
# Ticker change NHIC -> EVLV on 2021-07-19 has been processed
# 60.1% | Length of tickers_v4 is 8078
# Ticker change NILE -> AULT on 2023-01-03 has been processed
# 60.2% | Length of tickers_v4 is 8077
# Ticker change NK -> IBRX on 2021-03-10 has been processed
# 60.3% | Length of tickers_v4 is 8076
# Ticker change NLIT -> SHFS on 2022-09-29 has been processed
# 60.4% | Length of tickers_v4 is 8075
# Ticker change NLNK -> LUMO on 2020-03-19 has been processed
# 60.4% | Length of tickers_v4 is 8074
# Ticker change NLOK -> GEN on 2022-11-08 has been processed
# 60.4% | Length of tickers_v4 is 8073
# Ticker change NOVS -> APPH on 2021-02-01 has been processed
# 61.0% | Length of tickers_v4 is 8072
# ...
# 74.9% | Length of tickers_v4 is 7980
# Ticker change RPLA -> FOA on 2021-04-05 has been processed
# 75.0% | Length of tickers_v4 is 7979
# Ticker change RSVA -> ENVX on 2021-07-15 has been processed
# 75.3% | Length of tickers_v4 is 7978
# Ticker change RTIX -> SRGA on 2020-07-23 has been processed
# 75.4% | Length of tickers_v4 is 7977
# Ticker change RTP -> JOBY on 2021-08-11 has been processed
# 75.4% | Length of tickers_v4 is 7976
# Ticker change RTPY -> AUR on 2021-11-04 has been processed
# 75.4% | Length of tickers_v4 is 7975
# Ticker change RTPZ -> HIPO on 2021-08-03 has been processed
# 75.4% | Length of tickers_v4 is 7974
# Ticker change RTRX -> TVTX on 2020-11-19 has been processed
# 75.4% | Length of tickers_v4 is 7973
# Ticker change RTTR -> QLGN on 2020-05-26 has been processed
# 75.4% | Length of tickers_v4 is 7972
# Ticker change RUBI -> MGNI on 2020-07-01 has been processed
# 75.5% | Length of tickers_v4 is 7971
# Ticker change RVAC -> WEST on 2022-08-29 has been processed
# 75.6% | Length of tickers_v4 is 7970
# Ticker change RXN -> ZWS on 2021-10-05 has been processed
# 75.8% | Length of tickers_v4 is 7969
# Ticker change RYB -> GEHI on 2022-05-24 has been processed
# 75.9% | Length of tickers_v4 is 7968
# Ticker change SAII -> OTMO on 2021-08-16 has been processed
# 76.2% | Length of tickers_v4 is 7967
# Ticker change SALT -> NETI on 2021-02-08 has been processed
# 76.3% | Length of tickers_v4 is 7966
# Ticker change SAMA -> CLVR on 2020-12-18 has been processed
# 76.3% | Length of tickers_v4 is 7965
# Ticker change SAQN -> CURI on 2020-10-15 has been processed
# 76.4% | Length of tickers_v4 is 7964
# Ticker change SBE -> CHPT on 2021-03-01 has been processed
# 76.6% | Length of tickers_v4 is 7963
# Ticker change SBEA -> BRCC on 2022-02-10 has been processed
# 76.6% | Length of tickers_v4 is 7962
# Ticker change SBG -> OWLT on 2021-07-16 has been processed
# 76.7% | Length of tickers_v4 is 7961
# Ticker change SBGL -> SBSW on 2020-02-24 has been processed
# 76.7% | Length of tickers_v4 is 7960
# Ticker change SBOT -> EDSA on 2019-06-10 has been processed
# 76.8% | Length of tickers_v4 is 7959
# Ticker change SBPH -> FSTX on 2020-11-23 has been processed
# 76.8% | Length of tickers_v4 is 7958
# Ticker change SBTX -> SPRY on 2022-11-09 has been processed
# 76.9% | Length of tickers_v4 is 7957
# Ticker change SCPE -> RKLY on 2021-08-12 has been processed
# 77.1% | Length of tickers_v4 is 7956
# Ticker change SDH -> EPOW on 2022-08-15 has been processed
# 77.4% | Length of tickers_v4 is 7955
# Ticker change SEAH -> SGHC on 2022-01-28 has been processed
# 77.6% | Length of tickers_v4 is 7954
# Ticker change SERV -> TMX on 2020-10-05 has been processed
# 77.9% | Length of tickers_v4 is 7953
# Ticker change SESN -> CARM on 2023-03-08 has been processed
# 77.9% | Length of tickers_v4 is 7952
# Ticker change SFET -> ALAR on 2023-01-25 has been processed
# 78.0% | Length of tickers_v4 is 7951
# Ticker change SFTW -> BKSY on 2021-09-10 has been processed
# 78.1% | Length of tickers_v4 is 7950
# Ticker change SGAM -> RDBX on 2021-10-25 has been processed
# 78.2% | Length of tickers_v4 is 7949
# Ticker change SGLB -> SASI on 2022-05-19 has been processed
# 78.4% | Length of tickers_v4 is 7948
# Ticker change SGOC -> TROO on 2021-11-16 has been processed
# 78.5% | Length of tickers_v4 is 7947
# Ticker change SHLL -> HYLN on 2020-10-02 has been processed
# 78.7% | Length of tickers_v4 is 7946
# Ticker change SINO -> SGLY on 2022-01-07 has been processed
# 79.2% | Length of tickers_v4 is 7945
# Ticker change SLCR -> THCH on 2022-09-29 has been processed
# 79.7% | Length of tickers_v4 is 7944
# Ticker change SLGG -> SLE on 2023-09-11 has been processed
# 79.8% | Length of tickers_v4 is 7943
# Ticker change SMFR -> WGS on 2023-01-10 has been processed
# 80.2% | Length of tickers_v4 is 7942
# Ticker change SMIH -> YS on 2023-03-17 has been processed
# 80.2% | Length of tickers_v4 is 7941
# Ticker change SMMC -> BTRS on 2021-01-13 has been processed
# 80.3% | Length of tickers_v4 is 7940
# Ticker change SNBP -> PBLA on 2020-12-02 has been processed
# 80.6% | Length of tickers_v4 is 7939
# Ticker change SNCA -> PALI on 2021-04-28 has been processed
# 80.6% | Length of tickers_v4 is 7938
# Ticker change CUR -> PALI on 2019-11-01 has been processed
# 23.6% | Length of tickers_v4 is 7937
# Ticker change SNE -> SONY on 2021-04-01 has been processed
# 80.7% | Length of tickers_v4 is 7936
# Ticker change SNII -> RGTI on 2022-03-02 has been processed
# 80.8% | Length of tickers_v4 is 7935
# Ticker change SNPR -> VLTA on 2021-08-27 has been processed
# 80.9% | Length of tickers_v4 is 7934
# Ticker change SOAC -> TMC on 2021-09-10 has been processed
# 81.1% | Length of tickers_v4 is 7933
# Ticker change SONA -> FRST on 2021-03-31 has been processed
# 81.3% | Length of tickers_v4 is 7932
# Ticker change SPAQ -> FSR on 2020-10-30 has been processed
# 81.5% | Length of tickers_v4 is 7931
# Ticker change SPAQ -> ALLG on 2022-03-17 has been processed
# 81.5% | Length of tickers_v4 is 7930
# Ticker change SPAR -> SHYF on 2020-06-01 has been processed
# 81.5% | Length of tickers_v4 is 7929
# Ticker change SPFR -> VLD on 2021-09-30 has been processed
# 81.6% | Length of tickers_v4 is 7928
# Ticker change SPKE -> VIA on 2021-08-10 has been processed
# 81.7% | Length of tickers_v4 is 7927
# Ticker change SPNV -> OPAD on 2021-09-02 has been processed
# 81.9% | Length of tickers_v4 is 7926
# Ticker change SPRQ -> SUNL on 2021-07-12 has been processed
# 82.0% | Length of tickers_v4 is 7925
# Ticker change SRAC -> MNTS on 2021-08-13 has been processed
# 82.2% | Length of tickers_v4 is 7924
# Ticker change SRNG -> DNA on 2021-09-17 has been processed
# 82.5% | Length of tickers_v4 is 7923
# Ticker change SSPK -> MAPS on 2021-06-16 has been processed
# 82.8% | Length of tickers_v4 is 7922
# Ticker change SSW -> ATCO on 2020-02-28 has been processed
# 82.8% | Length of tickers_v4 is 7921
# Ticker change STIC -> BARK on 2021-06-02 has been processed
# 83.2% | Length of tickers_v4 is 7920
# Ticker change STPC -> BHIL on 2021-09-30 has been processed
# 83.4% | Length of tickers_v4 is 7919
# Ticker change STPK -> STEM on 2021-04-29 has been processed
# 83.4% | Length of tickers_v4 is 7918
# Ticker change STRN -> SWAG on 2022-12-16 has been processed
# 83.5% | Length of tickers_v4 is 7917
# Ticker change STWO -> GWH on 2021-10-11 has been processed
# 83.7% | Length of tickers_v4 is 7916
# Ticker change SV -> SMR on 2022-05-03 has been processed
# 84.0% | Length of tickers_v4 is 7915
# Ticker change SVAC -> CYXT on 2021-07-30 has been processed
# 84.0% | Length of tickers_v4 is 7914
# Ticker change SVFC -> SYM on 2022-06-08 has been processed
# 84.0% | Length of tickers_v4 is 7913
# Ticker change SVMK -> MNTV on 2021-06-15 has been processed
# 84.1% | Length of tickers_v4 is 7912
# Ticker change SVOK -> BOXD on 2021-12-09 has been processed
# 84.1% | Length of tickers_v4 is 7911
# Ticker change SWAG -> NOGN on 2022-08-30 has been processed
# 84.2% | Length of tickers_v4 is 7910
# Ticker change SWBK -> BRDS on 2021-11-04 has been processed
# 84.2% | Length of tickers_v4 is 7909
# Ticker change SWM -> MATV on 2022-07-06 has been processed
# 84.4% | Length of tickers_v4 is 7908
# Ticker change SYN -> TOVX on 2022-10-13 has been processed
# 84.6% | Length of tickers_v4 is 7907
# Ticker change SYNL -> ACNT on 2022-08-11 has been processed
# 84.7% | Length of tickers_v4 is 7906
# Ticker change SYX -> GIC on 2021-06-21 has been processed
# 84.8% | Length of tickers_v4 is 7905
# Ticker change TBA -> IS on 2021-06-29 has been processed
# 85.1% | Length of tickers_v4 is 7904
# Ticker change TBK -> TFIN on 2022-12-02 has been processed
# 85.2% | Length of tickers_v4 is 7903
# Ticker change TCAC -> SBIG on 2022-06-15 has been processed
# 85.3% | Length of tickers_v4 is 7902
# Ticker change TCRD -> FCRD on 2020-08-03 has been processed
# 85.6% | Length of tickers_v4 is 7901
# Ticker change TDAC -> LTRY on 2021-11-01 has been processed
# 85.7% | Length of tickers_v4 is 7900
# Ticker change THBR -> INDI on 2021-06-11 has been processed
# 86.5% | Length of tickers_v4 is 7899
# Ticker change THCB -> MVST on 2021-07-26 has been processed
# 86.6% | Length of tickers_v4 is 7898
# Ticker change THMA -> PEAR on 2021-12-06 has been processed
# 86.6% | Length of tickers_v4 is 7897
# Ticker change TKAT -> MI on 2023-09-18 has been processed
# 87.1% | Length of tickers_v4 is 7896
# Ticker change TKKS -> GSMG on 2020-02-19 has been processed
# 87.1% | Length of tickers_v4 is 7895
# Ticker change TLGA -> ELIQ on 2023-08-01 has been processed
# 87.2% | Length of tickers_v4 is 7894
# Ticker change TMCX -> BRMK on 2019-11-15 has been processed
# 87.5% | Length of tickers_v4 is 7893
# Ticker change TMTS -> NN on 2021-10-29 has been processed
# 87.6% | Length of tickers_v4 is 7892
# Ticker change TOCA -> FBRX on 2020-06-16 has been processed
# 87.8% | Length of tickers_v4 is 7891
# Ticker change TORC -> ACET on 2020-09-16 has been processed
# 87.9% | Length of tickers_v4 is 7890
# Ticker change TOT -> TTE on 2021-06-11 has been processed
# 88.0% | Length of tickers_v4 is 7889
# Ticker change TOTA -> CLNN on 2020-12-31 has been processed
# 88.0% | Length of tickers_v4 is 7888
# Ticker change TPBA -> LVRO on 2023-03-01 has been processed
# 88.1% | Length of tickers_v4 is 7887
# Ticker change TPGH -> ACEL on 2019-11-21 has been processed
# 88.1% | Length of tickers_v4 is 7886
# Ticker change TPGS -> VCSA on 2021-12-07 has been processed
# 88.2% | Length of tickers_v4 is 7885
# Ticker change TPRE -> SPNT on 2021-03-01 has been processed
# 88.2% | Length of tickers_v4 is 7884
# Ticker change TRCH -> MMAT on 2021-06-28 has been processed
# 88.4% | Length of tickers_v4 is 7883
# Ticker change TREB -> SST on 2022-01-28 has been processed
# 88.4% | Length of tickers_v4 is 7882
# Ticker change TRNE -> DM on 2020-12-10 has been processed
# 88.7% | Length of tickers_v4 is 7881
# Ticker change TROV -> CRDF on 2020-05-08 has been processed
# 88.8% | Length of tickers_v4 is 7880
# Ticker change TRWH -> BALY on 2020-11-09 has been processed
# 89.0% | Length of tickers_v4 is 7879
# Ticker change TRXC -> ASXC on 2021-03-05 has been processed
# 89.1% | Length of tickers_v4 is 7878
# Ticker change TSIA -> LTCH on 2021-06-07 has been processed
# 89.2% | Length of tickers_v4 is 7877
# Ticker change TUGC -> SAI on 2022-05-02 has been processed
# 89.6% | Length of tickers_v4 is 7876
# Ticker change TVAC -> ISPO on 2022-02-14 has been processed
# 89.7% | Length of tickers_v4 is 7875
# Ticker change TWCT -> CLBT on 2021-08-31 has been processed
# 89.8% | Length of tickers_v4 is 7874
# Ticker change TWMC -> KSPN on 2020-09-08 has been processed
# 89.9% | Length of tickers_v4 is 7873
# Ticker change TWND -> BURU on 2023-02-01 has been processed
# 89.9% | Length of tickers_v4 is 7872
# Ticker change TWNT -> LLAP on 2022-03-28 has been processed
# 89.9% | Length of tickers_v4 is 7871
# Ticker change TXAC -> PNT on 2020-08-07 has been processed
# 90.0% | Length of tickers_v4 is 7870
# Ticker change TYDE -> OCTO on 2023-04-04 has been processed
# 90.1% | Length of tickers_v4 is 7869
# Ticker change TYHT -> SISI on 2021-10-18 has been processed
# 90.1% | Length of tickers_v4 is 7868
# Ticker change TZAC -> RVPH on 2020-12-15 has been processed
# 90.2% | Length of tickers_v4 is 7867
# Ticker change UBNT -> UI on 2019-08-20 has been processed
# 90.4% | Length of tickers_v4 is 7866
# Ticker change UEPS -> LSAK on 2022-05-25 has been processed
# 90.6% | Length of tickers_v4 is 7865
# Ticker change UIHC -> ACIC on 2023-08-15 has been processed
# 90.8% | Length of tickers_v4 is 7864
# Ticker change UMRX -> COGT on 2020-10-06 has been processed
# 91.0% | Length of tickers_v4 is 7863
# Ticker change UPTD -> ESLA on 2023-10-02 has been processed
# 91.3% | Length of tickers_v4 is 7862
# Ticker change USAT -> CTLP on 2021-04-19 has been processed
# 91.5% | Length of tickers_v4 is 7861
# Ticker change UTME -> WTO on 2023-09-05 has been processed
# 91.8% | Length of tickers_v4 is 7860
# Ticker change VACQ -> RKLB on 2021-08-25 has been processed
# 92.0% | Length of tickers_v4 is 7859
# Ticker change VCKA -> SCLX on 2022-11-11 has been processed
# 92.2% | Length of tickers_v4 is 7858
# Ticker change VCVC -> REE on 2021-07-23 has been processed
# 92.3% | Length of tickers_v4 is 7857
# Ticker change VENA -> MLGO on 2022-12-13 has been processed
# 92.5% | Length of tickers_v4 is 7856
# Ticker change VGAC -> ME on 2021-06-17 has been processed
# 92.7% | Length of tickers_v4 is 7855
# Ticker change VGII -> GROV on 2022-06-17 has been processed
# 92.8% | Length of tickers_v4 is 7854
# Ticker change VHNA -> RDZN on 2023-09-21 has been processed
# 92.9% | Length of tickers_v4 is 7853
# Ticker change VIAC -> PARA on 2022-02-17 has been processed
# 92.9% | Length of tickers_v4 is 7852
# Ticker change VIACA -> PARAA on 2022-02-17 has been processed
# 92.9% | Length of tickers_v4 is 7851
# Ticker change VICL -> FRTX on 2019-09-03 has been processed
# 93.0% | Length of tickers_v4 is 7850
# Ticker change VIH -> BKKT on 2021-10-18 has been processed
# 93.1% | Length of tickers_v4 is 7849
# Ticker change VISI -> VOLT on 2019-09-09 has been processed
# 93.2% | Length of tickers_v4 is 7848
# Ticker change VLON -> GRI on 2023-04-24 has been processed
# 93.5% | Length of tickers_v4 is 7847
# Ticker change VMAC -> ANGH on 2022-02-04 has been processed
# 93.6% | Length of tickers_v4 is 7846
# Ticker change VOSO -> WEJO on 2021-11-19 has been processed
# 93.9% | Length of tickers_v4 is 7845
# Ticker change VPCC -> DAVE on 2022-01-06 has been processed
# 93.9% | Length of tickers_v4 is 7844
# Ticker change VRML -> AWH on 2020-06-12 has been processed
# 94.1% | Length of tickers_v4 is 7843
# Ticker change VSPR -> SKIN on 2021-05-06 has been processed
# 94.4% | Length of tickers_v4 is 7842
# Ticker change VTAQ -> PRST on 2022-09-22 has been processed
# 94.5% | Length of tickers_v4 is 7841
# Ticker change VTIQ -> NKLA on 2020-06-04 has been processed
# 94.6% | Length of tickers_v4 is 7840
# Ticker change WBAI -> BTCM on 2021-04-20 has been processed
# 95.3% | Length of tickers_v4 is 7839
# Ticker change WETF -> WT on 2022-11-07 has been processed
# 95.7% | Length of tickers_v4 is 7838
# Ticker change WLTW -> WTW on 2022-01-10 has been processed
# 96.3% | Length of tickers_v4 is 7837
# Ticker change WPF -> ALIT on 2021-07-06 has been processed
# 96.7% | Length of tickers_v4 is 7836
# Ticker change WRE -> ELME on 2022-10-20 has been processed
# 96.8% | Length of tickers_v4 is 7835
# Ticker change WRLS -> AVCT on 2020-04-08 has been processed
# 96.8% | Length of tickers_v4 is 7834
# Ticker change WRTC -> WRAP on 2020-12-01 has been processed
# 96.9% | Length of tickers_v4 is 7833
# Ticker change WSTG -> CLMB on 2022-10-31 has been processed
# 97.0% | Length of tickers_v4 is 7832
# Ticker change WTR -> WTRG on 2020-02-03 has been processed
# 97.2% | Length of tickers_v4 is 7831
# Ticker change WTRH -> ASAP on 2022-11-22 has been processed
# 97.2% | Length of tickers_v4 is 7830
# Ticker change WYND -> TNL on 2021-02-17 has been processed
# 97.4% | Length of tickers_v4 is 7829
# Ticker change XAN -> ACR on 2021-02-17 has been processed
# 97.5% | Length of tickers_v4 is 7828
# Ticker change XL -> SPRU on 2022-11-14 has been processed
# 97.7% | Length of tickers_v4 is 7827
# Ticker change XON -> PGEN on 2020-02-03 has been processed
# 97.9% | Length of tickers_v4 is 7826
# Ticker change XPOA -> QBTS on 2022-08-08 has been processed
# 98.0% | Length of tickers_v4 is 7825
# Ticker change XRF -> SOS on 2020-07-20 has been processed
# 98.1% | Length of tickers_v4 is 7824
# Ticker change XSPA -> XWEL on 2022-10-25 has been processed
# 98.1% | Length of tickers_v4 is 7823
# Ticker change YAC -> SSU on 2021-12-15 has been processed
# 98.3% | Length of tickers_v4 is 7822
# Ticker change YMTX -> KA on 2022-12-19 has been processed
# 98.5% | Length of tickers_v4 is 7821
# Ticker change YRCW -> YELL on 2021-02-08 has been processed
# 98.6% | Length of tickers_v4 is 7820
# Ticker change YSAC -> SKYH on 2022-01-26 has been processed
# 98.7% | Length of tickers_v4 is 7819
# Ticker change ZEST -> BNMV on 2023-03-21 has been processed
# 99.0% | Length of tickers_v4 is 7818
# Ticker change ZFGN -> LRMR on 2020-05-29 has been processed
# 99.0% | Length of tickers_v4 is 7817
# Ticker change ZIOP -> TCRT on 2022-01-27 has been processed
# 99.2% | Length of tickers_v4 is 7816
# Ticker change ZNTE -> EVEX on 2022-05-10 has been processed
# 99.4% | Length of tickers_v4 is 7815

# %%
tickers_v5 = get_tickers(v=5)
renamings = tickers_v5[tickers_v5["tickers_old"].str.len() > 2] # These were renamed
print(len(renamings))
tickers_v5[tickers_v5['ticker'] == 'META']
# Out:
# 738
#                    ID ticker             tickers_old  \
# 4426  META-2022-06-09   META  [['2022-06-09', 'FB']]
#
#                                            name  active  start_date  \
# 4426  Meta Platforms, Inc. Class A Common Stock    True  2019-06-03
#
#         end_date  start_data    end_data type        cik composite_figi
# 4426  2024-03-01  2019-06-03  2024-03-01   CS  1326801.0   BBG000MM2P62

# %% [markdown]
# Tickers that were renamed multiple times:

# %%
multiple_renamings = tickers_v5[tickers_v5["tickers_old"].str.len() > 30]
print(len(multiple_renamings))
multiple_renamings.head(2)
# Out:
# 9
#                    ID ticker  \
# 2411  ERNA-2022-10-17   ERNA
# 2751  FRGT-2022-05-27   FRGT
#
#                                            tickers_old  \
# 2411    [['2022-10-17', 'BTX'], ['2021-03-26', 'NTN']]
# 2751  [['2022-05-27', 'HUSN'], ['2020-05-08', 'CIFS']]
#
#                                             name  active  start_date  \
# 2411       Eterna Therapeutics Inc. Common Stock    True  2019-06-03
# 2751  Freight Technologies, Inc. Ordinary Shares    True  2019-06-03
#
#         end_date  start_data    end_data type        cik composite_figi
# 2411  2024-03-01  2019-06-03  2024-03-01   CS   748592.0   BBG000CX5677
# 2751  2024-03-01  2019-06-03  2024-03-01   CS  1687542.0

# %% [markdown]
# Now we have 5 tickers lists. These are:
# 1. Basic ticker list with a lot of incorrect duplications.
# 2. Duplications merged and incorrect tickers removed.
# 3. ETFs added.
# 4. Data start/end dates added.
# 5. Renamings merged.
# Only the last should be used in backtesting.
#
# If Polygon just provided these from the start, it would have saved countless hours. But at least I learned some Python I guess. And at least Polygon does not ask thousands.

# %% [markdown]
# # 8.2 Updates
# Rerun the file after setting END_DATE and updating the list of renamings.
